# %%
import pandas as pd
import numpy as np

# %%
cities = pd.read_csv("capital_cities.csv")
display(cities)
# Out:
#     continent            country      capital_city  capital_population
# 0      Europe      Åland Islands         Mariehamn               11709
# 1      Europe            Albania            Tirana              418495
# 2      Europe            Andorra  Andorra la Vella               22886
# 3      Europe            Austria            Vienna             1911191
# 4      Europe            Belarus             Minsk             2009786
# ..        ...                ...               ...                 ...
# 235   Oceania    Solomon Islands           Honiara               84520
# 236   Oceania              Tonga        Nuku‘alofa               35184
# 237   Oceania             Tuvalu          Funafuti                6025
# 238   Oceania            Vanuatu         Port-Vila               44040
# 239   Oceania  Wallis and Futuna          Mata-Utu                1126
#
# [240 rows x 4 columns]

# %%
cities.size
# Out:
# 960

# %%
cities.shape
# Out:
# (240, 4)

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   continent           240 non-null    object
#  1   country             240 non-null    object
#  2   capital_city        240 non-null    object
#  3   capital_population  240 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 7.6+ KB

# %%
cities[cities.continent == "Europe"]
# Out:
#    continent                 country      capital_city  capital_population
# 0     Europe           Åland Islands         Mariehamn               11709
# 1     Europe                 Albania            Tirana              418495
# 2     Europe                 Andorra  Andorra la Vella               22886
# 3     Europe                 Austria            Vienna             1911191
# 4     Europe                 Belarus             Minsk             2009786
# 5     Europe                 Belgium          Brussels             1175173
# 6     Europe  Bosnia and Herzegovina          Sarajevo              275524
# 7     Europe                Bulgaria             Sofia             1241675
# 8     Europe                 Croatia            Zagreb              792875
# 9     Europe                 Czechia            Prague             1301132
# 10    Europe                 Denmark        Copenhagen              616098
# ...

# %%
cities[cities.continent == "Europe"].head()
# Out:
#   continent        country      capital_city  capital_population
# 0    Europe  Åland Islands         Mariehamn               11709
# 1    Europe        Albania            Tirana              418495
# 2    Europe        Andorra  Andorra la Vella               22886
# 3    Europe        Austria            Vienna             1911191
# 4    Europe        Belarus             Minsk             2009786
