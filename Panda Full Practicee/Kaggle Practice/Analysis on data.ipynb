# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ### 1 Load the data

# %%
data = pd.read_csv("project_data.csv")
data
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %% [markdown]
# ## 2 Gain basic understanding

# %%
data.head(10) # bydefault first five rows
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
# 5     20201706            1967            Master   Relationship
# 6     20201707            1971        Graduation       Divorced
# 7     20201708            1985               PhD        Married
# 8     20201709            1974               PhD        Widowed
# 9     20201710            1950               PhD         Single
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      9/4/2012       58                 8                4
# 1        46344.0      3/8/2014       38                 1                2
# ...

# %%
data.tail(10) # bydefault last five rows
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 489     20202190            1952       High School          Widow
# 490     20202191            1958               PhD   Relationship
# 491     20202192            1976        Graduation       Divorced
# 492     20202193            1955        Graduation   Relationship
# 493     20202194            1964            Master         Single
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 489        28457.0    10/28/2012       96                 4                4
# 490        70991.0     9/24/2012       11                 2               12
# ...

# %% [markdown]
# ### check the basic information of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        499 non-null    int64
#  1   year_of_birth      499 non-null    int64
#  2   educational_level  499 non-null    object
#  3   marital_status     499 non-null    object
#  4   annual_income      486 non-null    float64
#  5   purhcase_date      499 non-null    object
#  6   recency            499 non-null    int64
#  7   online_purchases   499 non-null    int64
#  8   store_purchases    499 non-null    int64
#  9   complaints         499 non-null    int64
#  10  calls              499 non-null    int64
#  11  intercoms          499 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 46.9+ KB

# %%
data.isna().sum()
# Out:
# customer_id           0
# year_of_birth         0
# educational_level     0
# marital_status        0
# annual_income        13
# purhcase_date         0
# recency               0
# online_purchases      0
# store_purchases       0
# complaints            0
# calls                 0
# intercoms             0
# dtype: int64

# %%
data.shape
# Out:
# (499, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=499, step=1)

# %%
data.columns
# Out:
# Index(['customer_id', 'year_of_birth ', 'educational_level', 'marital_status',
#        'annual_income', 'purhcase_date', 'recency', 'online_purchases',
#        'store_purchases', 'complaints', 'calls', 'intercoms'],
#       dtype='object')

# %%
display(data["marital_status"].unique())
display(data["marital_status"].nunique())
# Out:
# array(['Single', 'Married', 'Divorced', 'Relationship', 'Widowed',
#        'Widow'], dtype=object)
# 6

# %%
display(data["educational_level"].unique())
display(data["educational_level"].nunique())
# Out:
# array(['Graduation', 'PhD', 'Master', 'Basic', 'High School'],
#       dtype=object)
# 5

# %%
data["educational_level"].value_counts(normalize=True) # instead of frequency it will return properties of a collumn
# Out:
# Graduation     0.515030
# PhD            0.228457
# Master         0.162325
# High School    0.080160
# Basic          0.014028
# Name: educational_level, dtype: float64

# %%
data["educational_level"].value_counts()
# Out:
# Graduation     257
# PhD            114
# Master          81
# High School     40
# Basic            7
# Name: educational_level, dtype: int64

# %%
data["annual_income"].isna().sum()
# Out:
# 13

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# customer_id           0
# year_of_birth         0
# educational_level     0
# marital_status        0
# annual_income        13
# purhcase_date         0
# recency               0
# online_purchases      0
# store_purchases       0
# complaints            0
# calls                 0
# intercoms             0
# dtype: int64

# %%
data[data["annual_income"].isna()]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 10      20201711            1983        Graduation         Single
# 27      20201728            1986        Graduation         Single
# 43      20201744            1959               PhD       Divorced
# 48      20201749            1951        Graduation        Married
# 58      20201759            1982        Graduation   Relationship
# 71      20201772            1988       High School         Single
# 90      20201791            1957               PhD   Relationship
# 91      20201792            1957        Graduation        Married
# 92      20201793            1973            Master   Relationship
# 128     20201829            1961               PhD        Married
# 133     20201834            1980        Graduation   Relationship
# 312     20202013            1990        Graduation         Single
# 319     20202020            1997        Graduation       Divorced
#
# ...

# %% [markdown]
# ### 3 Select and filter data: loc and iloc
# - select the Birthdate, Education, and Income of every customer

# %%
data.iloc[[1,2,3], [1,2,4]]
# Out:
#    year_of_birth  educational_level  annual_income
# 1            1950        Graduation        46344.0
# 2            1965        Graduation        71613.0
# 3            1984        Graduation        26646.0

# %%
data.iloc[:, [1,2,4]]
# Out:
#      year_of_birth  educational_level  annual_income
# 0              1982        Graduation        58138.0
# 1              1950        Graduation        46344.0
# 2              1965        Graduation        71613.0
# 3              1984        Graduation        26646.0
# 4              1981               PhD        58293.0
# ..              ...               ...            ...
# 494            1944               PhD        55614.0
# 495            1962            Master        59432.0
# 496            1978        Graduation        55563.0
# 497            1971               PhD        43624.0
# 498            1949               PhD        41461.0
#
# [499 rows x 3 columns]

# %%
# data.loc[:6, ['educational_level', 'recency']]
data.loc[0:,["educational_level", "annual_income", "recency"]]
# Out:
#     educational_level  annual_income  recency
# 0          Graduation        58138.0       58
# 1          Graduation        46344.0       38
# 2          Graduation        71613.0       26
# 3          Graduation        26646.0       26
# 4                 PhD        58293.0       94
# ..                ...            ...      ...
# 494               PhD        55614.0       85
# 495            Master        59432.0       88
# 496        Graduation        55563.0       22
# 497               PhD        43624.0       83
# 498               PhD        41461.0       63
#
# [499 rows x 3 columns]

# %% [markdown]
# #### get only subcategory columns

# %%
data[data["educational_level"] == "Master"]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 5       20201706            1967            Master   Relationship
# 13      20201714            1952            Master         Single
# 18      20201719            1980            Master         Single
# 30      20201731            1989            Master       Divorced
# 31      20201732            1963            Master         Single
# ..           ...             ...               ...            ...
# 481     20202182            1972            Master       Divorced
# 484     20202185            1960            Master   Relationship
# 486     20202187            1976            Master   Relationship
# 493     20202194            1964            Master         Single
# 495     20202196            1962            Master       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 5          62000.0      9/9/2013       16                 6               10
# ...

# %% [markdown]
# ###### below we are choosing all the customers with a Marital Status described as Single or Divorced only.

# %%
data[data["marital_status"].isin(["Single", "Divorced"])]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 2       20201703            1965        Graduation       Divorced
# 6       20201707            1971        Graduation       Divorced
# 9       20201710            1950               PhD         Single
# 10      20201711            1983        Graduation         Single
# ..           ...             ...               ...            ...
# 491     20202192            1976        Graduation       Divorced
# 493     20202194            1964            Master         Single
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %%
data.loc[(data["annual_income"] >= 75000) & (data["educational_level"]=="Master")]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 18      20201719            1980            Master         Single
# 51      20201752            1964            Master         Single
# 55      20201756            1955            Master        Married
# 60      20201761            1982            Master         Single
# 76      20201777            1993            Master        Married
# 109     20201810            1993            Master         Single
# 120     20201821            1957            Master   Relationship
# 140     20201841            1987            Master         Single
# 217     20201918            1985            Master        Widowed
# 277     20201978            1981            Master         Single
# 305     20202006            1983            Master        Widowed
# 423     20202124            1973            Master   Relationship
# 435     20202136            1983            Master   Relationship
#
# ...

# %%
data.loc[(data["year_of_birth "] >= 2000) & (data["marital_status"] == "Single") & (data["annual_income"]>=80000)]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 418     20202119            2000        Graduation         Single
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 418        91065.0     2/22/2013       33                 7                9
#
#      complaints  calls  intercoms
# 418           0      3         11

# %% [markdown]
# ### Analyse the first seven data from 'educational_level', 'recency'

# %%
data.loc[:6, ["educational_level", "recency"]]
# Out:
#   educational_level  recency
# 0        Graduation       58
# 1        Graduation       38
# 2        Graduation       26
# 3        Graduation       26
# 4               PhD       94
# 5            Master       16
# 6        Graduation       34

# %%
data.iloc[:7, [2,6]]
# Out:
#   educational_level  recency
# 0        Graduation       58
# 1        Graduation       38
# 2        Graduation       26
# 3        Graduation       26
# 4               PhD       94
# 5            Master       16
# 6        Graduation       34

# %% [markdown]
# ### 3.4 Apply data operations: index, new variables, data types and more!

# %% [markdown]
# ##### 1. set the index as customer_id

# %%
data.set_index("customer_id")
# Out:
#              year_of_birth  educational_level marital_status  annual_income  \
# customer_id
# 20201701               1982        Graduation         Single        58138.0
# 20201702               1950        Graduation        Married        46344.0
# 20201703               1965        Graduation       Divorced        71613.0
# 20201704               1984        Graduation   Relationship        26646.0
# 20201705               1981               PhD        Widowed        58293.0
# ...                     ...               ...            ...            ...
# 20202195               1944               PhD       Divorced        55614.0
# 20202196               1962            Master       Divorced        59432.0
# 20202197               1978        Graduation       Divorced        55563.0
# 20202198               1971               PhD   Relationship        43624.0
# 20202199               1949               PhD   Relationship        41461.0
#
# ...

# %% [markdown]
# ##### sort the data by year_of_birth, ascending is default

# %%
data.sort_values(["year_of_birth "])
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 339     20202040            1899               PhD         Single
# 32      20201733            1940        Graduation        Married
# 358     20202059            1943            Master        Married
# 39      20201740            1943               PhD       Divorced
# 494     20202195            1944               PhD       Divorced
# ..           ...             ...               ...            ...
# 16      20201717            2000        Graduation        Married
# 418     20202119            2000        Graduation         Single
# 116     20201817            2000        Graduation   Relationship
# 185     20201886            2000        Graduation         Single
# 452     20202153            2000            Master         Single
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 339        83532.0     9/26/2013       36                 4                4
# ...

# %% [markdown]
# ##### create a new variable which is the sum of all purchases performed by customers

# %%
data["sum_purcheses"] = data.online_purchases + data.store_purchases

# %%
data
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 0       20201701            1982        Graduation         Single
# 1       20201702            1950        Graduation        Married
# 2       20201703            1965        Graduation       Divorced
# 3       20201704            1984        Graduation   Relationship
# 4       20201705            1981               PhD        Widowed
# ..           ...             ...               ...            ...
# 494     20202195            1944               PhD       Divorced
# 495     20202196            1962            Master       Divorced
# 496     20202197            1978        Graduation       Divorced
# 497     20202198            1971               PhD   Relationship
# 498     20202199            1949               PhD   Relationship
#
#      annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0          58138.0      9/4/2012       58                 8                4
# ...

# %% [markdown]
# ##### create an income category (low, meduim, high) based on the income variable

# %%
income_categories = ["Low", "Medium", "High"] #set the categories
bins = [0,75000,120000,600000] #set the income boundaries 
cats = pd.cut(data["annual_income"],bins, labels=income_categories) #apply the pd.cut method
data["Income_Category"] = cats
data[["annual_income", "Income_Category"]]
# Out:
#      annual_income Income_Category
# 0          58138.0             Low
# 1          46344.0             Low
# 2          71613.0             Low
# 3          26646.0             Low
# 4          58293.0             Low
# ..             ...             ...
# 494        55614.0             Low
# 495        59432.0             Low
# 496        55563.0             Low
# 497        43624.0             Low
# 498        41461.0             Low
#
# [499 rows x 2 columns]

# %%
data[["annual_income", "Income_Category"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   annual_income    486 non-null    float64
#  1   Income_Category  486 non-null    category
# dtypes: category(1), float64(1)
# memory usage: 4.6 KB

# %%
data["Income_Category"].unique()
# Out:
# ['Low', NaN, 'Medium', 'High']
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
data[data["Income_Category"].isna()]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 10      20201711            1983        Graduation         Single
# 27      20201728            1986        Graduation         Single
# 43      20201744            1959               PhD       Divorced
# 48      20201749            1951        Graduation        Married
# 58      20201759            1982        Graduation   Relationship
# 71      20201772            1988       High School         Single
# 90      20201791            1957               PhD   Relationship
# 91      20201792            1957        Graduation        Married
# 92      20201793            1973            Master   Relationship
# 128     20201829            1961               PhD        Married
# 133     20201834            1980        Graduation   Relationship
# 312     20202013            1990        Graduation         Single
# 319     20202020            1997        Graduation       Divorced
#
# ...

# %% [markdown]
# ##### we can change the datatype of purchase_date to datetime and year_birth to integer

# %%
data["year_of_birth "].dtypes
# Out:
# dtype('int64')

# %%
data["year_of_birth "] = data["year_of_birth "].astype(dtype="int")

# %%
data["purhcase_date"].dtypes
# Out:
# dtype('O')

# %%
data["purhcase_date"] = pd.to_datetime(data["purhcase_date"])

# %%
data["purhcase_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
data[["purhcase_date"]]
# Out:
#     purhcase_date
# 0      2012-09-04
# 1      2014-03-08
# 2      2013-08-21
# 3      2014-02-10
# 4      2014-01-19
# ..            ...
# 494    2013-11-27
# 495    2013-04-13
# 496    2014-04-05
# 497    2013-04-21
# 498    2014-05-22
#
# [499 rows x 1 columns]

# %%
data.head()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0    2012-09-04       58                 8                4
# 1        46344.0    2014-03-08       38                 1                2
# 2        71613.0    2013-08-21       26                 8               10
# 3        26646.0    2014-02-10       26                 2                4
# 4        58293.0    2014-01-19       94                 5                6
#
#    complaints  calls  intercoms  sum_purcheses Income_Category
# 0           0      3         11             12             Low
# ...

# %% [markdown]
# ##### find out the age of customers based on the current year
# - today = date.today()
# - Age = Present date - Date of birth

# %%
today = dt.datetime.today().date()
today.year
# Out:
# 2022

# %%
age = today.year - data["year_of_birth "]
age
# Out:
# 0      40
# 1      72
# 2      57
# 3      38
# 4      41
#        ..
# 494    78
# 495    60
# 496    44
# 497    51
# 498    73
# Name: year_of_birth , Length: 499, dtype: int32

# %%
data.insert(2,"Customer_Age",value=age)

# %%
data
# Out:
#      customer_id  year_of_birth   Customer_Age educational_level  \
# 0       20201701            1982            40        Graduation
# 1       20201702            1950            72        Graduation
# 2       20201703            1965            57        Graduation
# 3       20201704            1984            38        Graduation
# 4       20201705            1981            41               PhD
# ..           ...             ...           ...               ...
# 494     20202195            1944            78               PhD
# 495     20202196            1962            60            Master
# 496     20202197            1978            44        Graduation
# 497     20202198            1971            51               PhD
# 498     20202199            1949            73               PhD
#
#     marital_status  annual_income purhcase_date  recency  online_purchases  \
# 0           Single        58138.0    2012-09-04       58                 8
# ...

# %% [markdown]
# ##### extract the week_date from the purchase_date which shows the year of purchase and the calendar week
# ##### make sure to change the purhcase_date varibale to datetime as shown above before applying the .isocalendar() method
# data["week_date"] = [int(f'{i.isocalendar()[0]}{i.isocalendar()[1]}') for i in data.purhcase_date]
# data["week_date

# %%
# for i in data.purhcase_date:
#     print(f"{i.isocalendar()[0]},{i.isocalendar()[1]}")

# %%
data["week_day"] = [f"{i.isocalendar()[0]}-{i.isocalendar()[1]}" for i in data.purhcase_date]

# %%
data.head(3)
# Out:
#    customer_id  year_of_birth   Customer_Age educational_level marital_status  \
# 0     20201701            1982            40        Graduation         Single
# 1     20201702            1950            72        Graduation        Married
# 2     20201703            1965            57        Graduation       Divorced
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0    2012-09-04       58                 8                4
# 1        46344.0    2014-03-08       38                 1                2
# 2        71613.0    2013-08-21       26                 8               10
#
#    complaints  calls  intercoms  sum_purcheses Income_Category week_day
# 0           0      3         11             12             Low  2012-36
# 1           0      3         11              3             Low  2014-10
# 2           0      3         11             18             Low  2013-34

# %% [markdown]
# ##### apply groupby to find the mean of income, recency, number of web and store purchases by educational group
# aggregate_view = pd.DataFrame(data.groupby(by='educational_level')[['annual_income', 'recency', 'store_purchases',  'online_purchases']].mean()).reset_index()
# aggregate_view

# %%
aggregate_view = pd.DataFrame(data.groupby(by="educational_level")[["annual_income", "recency", "online_purchases", "store_purchases"]].mean()).reset_index(drop=True)

# %%
aggregate_view
# Out:
#    annual_income    recency  online_purchases  store_purchases
# 0   19514.571429  53.571429          1.571429         2.857143
# 1   51607.827309  47.171206          3.887160         5.840467
# 2   44154.717949  58.400000          3.450000         4.600000
# 3   51191.700000  45.000000          4.049383         5.691358
# 4   55878.990991  49.008772          4.429825         6.298246

# %% [markdown]
# ##### apply pivot table to find the aggregated sum of purchases and mean of recency per education and marital status group
# pivot_table = pd.DataFrame(pd.pivot_table(data, values=['sum_purchases', 'recency'], index=['marital_status'],
#                         columns=['educational_level'], aggfunc={'recency': np.mean, 'sum_purchases': np.sum}, fill_value=0)).reset_index()
# pivot_table

# %%
pivot_table = pd.DataFrame(pd.pivot_table(data,values=["sum_purcheses", "recency"], index=["educational_level", "marital_status"], aggfunc={"sum_purcheses": np.sum, "recency": np.mean}))

# %%
pivot_table
# Out:
#                                     recency  sum_purcheses
# educational_level marital_status
# Basic             Divorced        68.333333             13
#                   Relationship    39.333333             15
#                   Single          52.000000              3
# Graduation        Divorced        54.897959            481
#                   Married         42.701493            652
#                   Relationship    48.196078            464
#                   Single          44.278689            623
#                   Widow           61.000000             34
#                   Widowed         46.760000            246
# High School       Divorced        64.666667             31
#                   Married         66.866667            120
#                   Relationship    49.615385             99
#                   Single          49.000000             54
#                   Widow           96.000000              8
# ...
