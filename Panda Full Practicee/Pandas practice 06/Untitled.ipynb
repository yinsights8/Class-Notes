# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("project_data.csv")
dataset.head()
# Out:
#    customer_id  year_of_birth  educational_level marital_status  \
# 0     20201701            1982        Graduation         Single
# 1     20201702            1950        Graduation        Married
# 2     20201703            1965        Graduation       Divorced
# 3     20201704            1984        Graduation   Relationship
# 4     20201705            1981               PhD        Widowed
#
#    annual_income purhcase_date  recency  online_purchases  store_purchases  \
# 0        58138.0      9/4/2012       58                 8                4
# 1        46344.0      3/8/2014       38                 1                2
# 2        71613.0     8/21/2013       26                 8               10
# 3        26646.0     2/10/2014       26                 2                4
# 4        58293.0     1/19/2014       94                 5                6
#
#    complaints  calls  intercoms
# 0           0      3         11
# 1           0      3         11
# ...

# %%
dataset.isna().sum()
# Out:
# customer_id           0
# year_of_birth         0
# educational_level     0
# marital_status        0
# annual_income        13
# purhcase_date         0
# recency               0
# online_purchases      0
# store_purchases       0
# complaints            0
# calls                 0
# intercoms             0
# dtype: int64

# %%
dataset[dataset.isna().any(axis=1)].count()
# Out:
# customer_id          13
# year_of_birth        13
# educational_level    13
# marital_status       13
# annual_income         0
# purhcase_date        13
# recency              13
# online_purchases     13
# store_purchases      13
# complaints           13
# calls                13
# intercoms            13
# dtype: int64

# %%
dataset[dataset.isna().any(axis=1)]
# Out:
#      customer_id  year_of_birth  educational_level marital_status  \
# 10      20201711            1983        Graduation         Single
# 27      20201728            1986        Graduation         Single
# 43      20201744            1959               PhD       Divorced
# 48      20201749            1951        Graduation        Married
# 58      20201759            1982        Graduation   Relationship
# 71      20201772            1988       High School         Single
# 90      20201791            1957               PhD   Relationship
# 91      20201792            1957        Graduation        Married
# 92      20201793            1973            Master   Relationship
# 128     20201829            1961               PhD        Married
# 133     20201834            1980        Graduation   Relationship
# 312     20202013            1990        Graduation         Single
# 319     20202020            1997        Graduation       Divorced
#
# ...

# %%
dataset.set_index("educational_level")
# Out:
#                    customer_id  year_of_birth  marital_status  annual_income  \
# educational_level
# Graduation            20201701            1982         Single        58138.0
# Graduation            20201702            1950        Married        46344.0
# Graduation            20201703            1965       Divorced        71613.0
# Graduation            20201704            1984   Relationship        26646.0
# PhD                   20201705            1981        Widowed        58293.0
# ...                        ...             ...            ...            ...
# PhD                   20202195            1944       Divorced        55614.0
# Master                20202196            1962       Divorced        59432.0
# Graduation            20202197            1978       Divorced        55563.0
# PhD                   20202198            1971   Relationship        43624.0
# PhD                   20202199            1949   Relationship        41461.0
#
# ...
