# %% [markdown]
# ## Reading csv,excel,json

# %%
import pandas as pd

# %% [markdown]
# ### 1. reading a csv file3

# %%
csv_file = pd.read_csv("movies_data.csv")
display(csv_file.head())
display(csv_file.tail())
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# ...

# %% [markdown]
# ## 2. reading excel file

# %%
excel_file = pd.read_excel("Emp_Records.xlsx")
display(excel_file)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
read = pd.ExcelFile("Emp_Records.xlsx")
read.sheet_names
# Out:
# ['Emp_Records', 'emp_salary', 'emp_names']

# %%
read.parse("emp_salary")
# Out:
#     Salary          City
# 0   168251        Denver
# 1    51063     Stonewall
# 2    50155  Michigantown
# 3   180294      Hydetown
# 4   117642       Fremont
# ..     ...           ...
# 95  129774        Biloxi
# 96  156194  Carol Stream
# 97   95673       Detroit
# 98   51015      Mc Grath
# 99   93650          Alma
#
# [100 rows x 2 columns]

# %%
read.parse("Emp_Records")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
read.parse("emp_names")
# Out:
#     Emp ID First Name
# 0   677509       Lois
# 1   940761     Brenda
# 2   428945        Joe
# 3   408351      Diane
# 4   193819   Benjamin
# ..     ...        ...
# 95  639892       Jose
# 96  704709     Harold
# 97  461593     Nicole
# 98  392491    Theresa
# 99  495141      Tammy
#
# [100 rows x 2 columns]

# %% [markdown]
# ### handling missing values

# %%
movie = pd.read_csv("movies_data.csv")
display(movie)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movie.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movie.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movie.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movie.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movie[movie.isna().any(axis=1)]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movie[movie["content_rating"].isna()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movie[movie.isnull().any(axis=1)]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movie[movie["content_rating"].isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
c_movie = movie.copy(deep=True)

# %%
c_mv = movie.copy(deep=True)

# %%
c_movie.fillna(value=c_movie["star_rating"].mean(),inplace=True)
movie
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
c_movie[c_movie.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
c_movie.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
c_mv.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
c_mv[c_mv.isna().any(axis=1)]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
c_mv.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movie.dropna(thresh=2,inplace=True)

# %%
movie.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
c_mv.drop(labels=[187,649,936]).head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
c_mv.drop(labels=[187,649,936]).isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
c_mv.T.drop_duplicates().T
# Out:
#     star_rating                                            title  \
# 0           9.3                         The Shawshank Redemption
# 1           9.2                                    The Godfather
# 2           9.1                           The Godfather: Part II
# 3           9.0                                  The Dark Knight
# 4           8.9                                     Pulp Fiction
# ..          ...                                              ...
# 974         7.4                                          Tootsie
# 975         7.4                      Back to the Future Part III
# 976         7.4  Master and Commander: The Far Side of the World
# 977         7.4                                      Poltergeist
# 978         7.4                                      Wall Street
#
#     content_rating      genre duration  \
# 0                R      Crime      142
# 1                R      Crime      175
# 2                R      Crime      200
# ...

# %% [markdown]
# ## sorting values()

# %%
c_mv.sort_values("star_rating",inplace=True)
c_mv.head()
# Out:
#      star_rating        title content_rating   genre  duration  \
# 978          7.4  Wall Street              R   Crime       126
# 950          7.4        Bound              R   Crime       108
# 949          7.4   Home Alone             PG  Comedy       103
# 948          7.4   Frances Ha              R  Comedy        86
# 947          7.4   Eraserhead        UNRATED   Drama        89
#
#                                            actors_list
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 950  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 949  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...

# %%
c_mv.reset_index(drop=True,inplace=True)

# %%
c_mv.head()
# Out:
#    star_rating        title content_rating   genre  duration  \
# 0          7.4  Wall Street              R   Crime       126
# 1          7.4        Bound              R   Crime       108
# 2          7.4   Home Alone             PG  Comedy       103
# 3          7.4   Frances Ha              R  Comedy        86
# 4          7.4   Eraserhead        UNRATED   Drama        89
#
#                                          actors_list
# 0  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 1  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 2  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 3  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 4  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...

# %%
c_mv["content_rating"].unique()
# Out:
# array(['R', 'PG', 'UNRATED', 'PG-13', 'G', nan, 'NC-17', 'APPROVED',
#        'NOT RATED', 'X', 'PASSED', 'GP', 'TV-MA'], dtype=object)

# %%
c_mv["content_rating"].nunique()
# Out:
# 12

# %%
c_mv["genre"].unique()
# Out:
# array(['Crime', 'Comedy', 'Drama', 'Adventure', 'Animation', 'Biography',
#        'Horror', 'Action', 'Mystery', 'Thriller', 'Western', 'Sci-Fi',
#        'Fantasy', 'Film-Noir', 'Family', 'History'], dtype=object)

# %%
c_mv["genre"].nunique()
# Out:
# 16

# %%
c_mv.value_counts("content_rating")
# Out:
# content_rating
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# dtype: int64

# %%
c_mv.value_counts("genre")
# Out:
# genre
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# dtype: int64

# %%
c_mv.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object
