# %% [markdown]
# ![image1.jpg](attachment:image1.jpg)

# %% [markdown]
# ## 180/degree = 30,45,60,90,180

# %%
print(180/30)   ## pi/6 = 30 
print(180/45)   ## pi/4 = 45 
print(180/60)   ## pi/3 = 60
print(180/90)   ## pi/2 = 90
# Out:
# 6.0
# 4.0
# 3.0
# 2.0

# %% [markdown]
# ![WhatsApp%20Image%202022-10-07%20at%206.56.24%20PM.jpeg](attachment:WhatsApp%20Image%202022-10-07%20at%206.56.24%20PM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202022-10-07%20at%2011.57.33%20AM.jpeg](attachment:WhatsApp%20Image%202022-10-07%20at%2011.57.33%20AM.jpeg)

# %% [markdown]
# ### trignomeric values
# - This way we can get the values of trignomety
#
#     - sin_degree = np.sin(radian_value)     # radian values  Pi/6, Pi/4, Pi/3, Pi/2, Pi, 3Pi/2, 2Pi
#     -
#     - cos_degree = np.cos(radian_value)
#     -
#     - tan_degree = np.tan(radian_value)
#     -
#     - cosec_degree = np.cosec(radian_value)
#     -
#     - sec_degree = np.sec(rdian_value)
#     -
#     - cot_degree = np.cot(radian_value)

# %%
import numpy as np

# %%
Pi = np.pi

# %% [markdown]
# ## To Find the squareroot of a number
# - this function is use to find the squareroot of the number
# - syntax
#     - np.sqrt(number)

# %% [markdown]
# ## Degree to Radian conversion
# - syntax
#     - np.deg2rad(degree)

# %%
np.deg2rad(30)
# Out:
# 0.5235987755982988

# %%
np.deg2rad(90)
# Out:
# 1.5707963267948966

# %% [markdown]
# ## Radian to Degree Conversion
# - syntax:-
#     - np.np.rad2deg(radian_value)

# %%
np.rad2deg(0.5235987755982988)
# Out:
# 29.999999999999996

# %%
np.rad2deg(1.5707963267948966)
# Out:
# 90.0
