# %% [markdown]
# # Create DataFrame
# - 1. list
# - 2. dict
# - 3. Series
# - 4. numpy array
#
# # Access, Delete DataFrame Columns and Rows
# - df[col_name]
# - df[col_list]
# - df[1:8]
# - df.iloc[index]
# - df.iloc[row_index, col_index]
# - df.loc[row_label]
# - df.loc[row_label, col_label]
# - df.head()
# - df.tail() Default = 5
#
# # Operations
# - df["column_lable"].add(df["column_lable"])
# - df["column_lable"].subtract(df["column_lable"])
# - df["column_lable"].divide(df["column_lable"])
# - df["column_lable"].multiply(df["column_lable"])
#
# - df['column_lable'].map()
#
# # Attributes
# - df.columns
# - df.index
# - df.axes
# - df.dtypes
# - df.shape
# - df.info()
# - df.describe()
# - df.corr() - it will return corelation between input and output variables
#
# # Read CSV and Excel
# - pd.read_csv()
# - pd.read_excel()
# - pd.read_json()
# - pd.ExcelWriter()
#
# # Read Sub (Sheet name) excel file
# - The easiest way to retrieve the sheet-names from an excel (xls., xlsx) is:
# - xl = pd.ExcelFile("FileName.xlsx")
#     - see all sheet names
#         - xl.sheet_names
#     - read a specific sheet to DataFrame
#         - xl.parse("SheetName")
#
# # Saving Files
# - df.to_csv()
# - df.to_excel()
# - df.to_json()
# - df.to_dict()
# - df.to_numpy()
#
# # Handle Missing Values
# - 1. Identify
#     - df.isna()
#     - df.isnull()
#     - df.isna().sum()
#     - df.isnull.mean()
#
# - 2. Filling missing values
#     - df.fillna()
#     - df[col_name].mean()
#     - df[col_name].median()
#     - df[col_name].mode()
#     - df[col_name].min()
#     - df[col_name].max()
#     - df[col_name].std()
#     - df[col_name].var()
#
# # Drop
# - df.dropna(thresh = df.shape[1])
# - df.drop(col_name, axis=1)
# - df.drop(col_list, axis=1)
# - df.drop(row_name, axis=0)
# - df.drop_duplicates()
# - df.T.drop_duplicates().T :- This will delete the duplicate columns
#
# # Sorting
# - df.sort_index()
# - df.sort_values()
# - df.reset_index()
# - df.set_index()
#
# # Functions
# - df.reindex()
# - df.unique()
# - df.nunique()
# - df.value_counts()
# - df.astype()
# - df.replace()
# - df.rename()
# - df.insert()
# - df.apply()
# - df.gruopby()
#     - df.gruopby().get_group()
#     - df.gruopby().first()
#     - df.gropby().num()
#
#
# # Join
# - 1. append()¶
#     - df1.append(df2)
#     - df1.append([df2,df3,...dfn])
#     - df1.append(list_of_df)
#
# - 2. concat()
#     - pd.concat([df1,df2,....,dfn],join = "outer",axis=0)
#
#     - outer - it will inclued all the ColumnLables(axis=1) and Indexes (axis=0)
#     - Inner - it only returns intersection indexLables(axis=1) or ColumnLables(axis=0)
#
# - 3. merge()
#     - pd.merge(left_df,right_df,how="inner")
#
# - 4. join()
#     - df1.join(df2,how="left")
#
#     - right = all columns and rows from right DF and intersection Rows & Columns from both left and right columns
#     - left = all columns and rows from left DF and intersection Rows & Columns from both left and right columns
#     - outer - it will inclued all the ColumnLables(axis=1) and Indexes (axis=0)
#     - Inner - it only returns intersection indexLables(axis=1) or ColumnLables(axis=0)

# %% [markdown]
# ### Diffternce between Merge and join :-
# Both join and merge can be used to combines two dataframes but the join method combines two dataframes on the basis of their indexes whereas the merge method is more versatile and allows us to specify columns beside the index to join on for both dataframes
