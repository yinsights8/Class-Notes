# %% [markdown]
# # 1. Creating New Anaconda enviroment

# %% [raw]
# - first got to the Disk where you want to create the enviroment
#     - >>E:
#
#
# - >>conda create -n env_name
#     - ex.
#          - >>conda create -n price_prediction
#
# - >>conda create -n env_name python 3.8
#     - ex.
#         - >>conda create -n price_prediction python = 3.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Activate Conda Env

# %% [raw]
# - >>conda activate env_name
#     - ex. >>conda activate price_prediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Deactivate

# %% [raw]
# - >>conda deactivate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Install libraries in env for project

# %% [raw]
# - >> conda install library_name
#     - ex.
#         >>conda install -c anaconda pandas
#         >>conda install -c anaconda flask
# OR
#
# - >>conda install flask
# - >>conda install pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Check env list

# %% [raw]
# - >>conda env list

# %% [markdown]
# # 6. Delete conda env
# - first deactivate the project env (- >>conda deactivate). then perform bellow command

# %% [raw]
# - >>conda env remove -n env_name

# %% [markdown]
# # 7. Check install pkg

# %% [raw]
# - >>conda list
