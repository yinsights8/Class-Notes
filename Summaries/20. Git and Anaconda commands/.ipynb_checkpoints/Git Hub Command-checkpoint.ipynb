# %% [markdown]
# ### Threre are three version Control systems
# - 1. GitHub
# - 2. Gitlab
# - 3. BitBucket

# %% [markdown]
# ### Create repo first on git hub

# %% [markdown]
# ## 1. Clone

# %% [raw]
# - 1. git clone url
#     - ex. git clone https://github.com/yinsights8/price_prediction.git
#
# - cd folder_name

# %% [markdown]
# # 2. Check Status of your project

# %% [raw]
# - git status

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Add Files

# %% [raw]
# ## Use this command
# - >>git add file_name
#     - >>git status
#     - added project files will we reflect in green text and the file which shows in red color's are not added.
#
# # not recommonded to use this commands
# - >>git add .
# - >>git add --all

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Commit your changes

# %% [raw]
# - git commit -m 'User Message'
#     - >>git commit -m "make some changes in this all the files"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Push

# %% [raw]
# - >>git push

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Creating New Branches

# %% [raw]
# - >>git checkout -b branch_name
#
# - examples :-
#     - >>git checkout -b testing
#     - >>git checkout -b management

# %% [markdown]
# # 7. Switch brance

# %% [raw]
# - >>git checkout branch_name

# %% [markdown]
# # 8. Check branch Name

# %% [raw]
# - >>git branch

# %% [markdown]
# # 9. Pull Repo

# %% [raw]
# - >>git pull
#
# - >>git pull origin branch_name

# %% [markdown]
# # 1. Git Merge

# %% [raw]
# - >>git merge branch_name1 branch_name2
