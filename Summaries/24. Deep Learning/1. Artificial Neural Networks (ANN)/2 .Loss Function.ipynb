# %% [raw]
# Input >>  processing (hidden layer) >>  Ouput  >>  Loss  <<  update weights and baises
#
# input >> NN >> Loss >> update weights and baises

# %% [markdown]
# #### Difference between the Loss and Cos function

# %% [raw]
# Loss Function :- it a single recored error
# cost Function :- it is whole batch Error

# %% [markdown]
# ## Loss Function
# https://towardsdatascience.com/loss-functions-and-their-use-in-neural-networks-a470e703f1e9#:~:text=A%20loss%20function%20is%20a,the%20predicted%20and%20target%20outputs.

# %% [markdown]
# # 1. Regression problem

# %% [raw]
# It is a Evaluation Method of evaluating how well our algorithm is performing on the given dataset

# %% [raw]
# Types of loss functions
# 1. Regression loss Function :- used in a regression neural networks given an input value, the model                                predicts a corresponding output value.
# 				 			   Ex. Mean Squared Error, Mean Absolute Error
#
# 2. Clssification Loss Function:- used in classification neural netwrok, given an input the neural 								network produces a vector of probabilities of the input belonging to various pre-set categories — can then select the category with the highest probability of belonging; Ex. Binary Cross-Entropy, sparse categorical entropy (Categorical Cross-Entropy).

# %% [markdown]
# ### Mean Squared Error

# %% [raw]
# MSE finds the average of squared differences between the observed and the predicted ouputs.
# this function dosent consern with the -ve sign because we are squaring the errors. However the value with a large error are penalized ,this mse function happens to be a convex function. with a clearly defined global minimum — this allows us to more easily utilize gradient descent optimization to set the weight values.

# %% [markdown]
# Equation is :
# ![image.png](attachment:image.png)
#
# - n = number of samples
# - y = Y actual value
# - ŷ = Y predicted value

# %% [raw]
# Advantages :-
#     1. This is in a quadratic form when we plot we will get the Gradient Descent only with one Global minima
#     2. No Local Minima
#     3. Easy to interpret.

# %% [raw]
# Disadvantages :
#      1. it is very sensitive to outliers, if a predicted value is significantly greater than or less than its target value, this will significantly increase the loss.
#      2. Error unit is not the same
#
# For example, y = 20, ŷ = 15
#             loss = 5
#             mse = Sum(y - ŷ) = 25

# %%
y = 20; ŷ = 15
mse = (y-ŷ)**2
print("MSE:- ",mse)
# Out:
# MSE:-  25

# %% [markdown]
# ### Mean Absolute Error (MAE)

# %% [raw]
# MAE find the differences between the target and the predicted outputs. This function is use as the alternative of MSE, because the MSE is highly sensitive to outliers because it is squaring the distances between the actual and the predicted values. MAE is used in cases when the training data has a large number of outliers to mtigate this.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Advantages :
#     1. Unit of the differeces is same
#     2. Outliers are better handdled as it is not penlizing the model by squaring the Errors
#     3. Same unit as output

# %% [raw]
# Disadvantages :
#     1. Graph is not differentiable
#     2. it may lead to Multiple local minima
#     3. as the average distance is approches to zero, gradient optimization will not work, as the function's derivative at 0 is undefined. (which will result in an error, as it is impossible to divide by 0).
#
# For example, y = 20, ŷ = 15
#             loss = 5
#             mse = Sum |y - ŷ| = 5

# %%
y = 20; ŷ = 15
mae = abs(y - ŷ)
print("MAE:- ",mae)
# Out:
# MAE:-  5

# %% [markdown]
# ### Huber Loss Function

# %% [raw]
# because of the disadvantages of Both MSE and MAE therefore Because of this, a loss function called a 'Huber Loss' was developed, which has the advantages of both MSE and MAE.
#
# If the absolut differeces between the actual and predicted value is less than or equal to threshold value (δ) then MSE is applied, Otherwise — if the error is sufficiently large — MAE is applied.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Advantages
#    1. outliers are handdled properly
#    2. local minima situations are handdled properly

# %% [raw]
# Disadvantages :
#     1. Complex

# %% [markdown]
# # 2. Classification Problem

# %% [markdown]
# ### 1. Binary-cross Entropy / Log Loss

# %% [raw]
# This is the loss function used in binary classification models — where the model takes in an input and has to classify it into one of two pre-set categories.
#
# Classification neural networks work by outputting a vector of probabilities — the probability that the given input fits into each of the pre-set categories; then selecting the category with the highest probability as the final output.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [raw]
# 1. when Y act = 0,
# 	 then, log(1 - ŷi)
#
# 2. When Y act = 1,
# 	 then, log( ŷi )
#
# ŷ ~ Pi = Probability value

# %% [markdown]
# ### 2. Categorical Cross-Entropy Loss

# %% [raw]
# When the number of classes is greater than TWO (Multiclass classificaiton) we untilize categorical Entropy, This follows very similar process as binary cross-Entropy

# %% [markdown]
# Binary cross-entropy is a special case of categorical cross-entropy,
# - where M = 2 — the number of categories is 2.
# - N = number of samples
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Sparse Categorical cross Entropy

# %% [markdown]
# It is used when there are two or more classes present in our classification task. similarly to categorical cross entropy. But there is one minor difference, between categorical crossentropy and sparse categorical cross entropy that’s in sparse categorical cross-entropy labels are expected to be provided in integers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Dropout Ratio
# 1. https://towardsdatascience.com/dropout-in-neural-networks-47a162d621d9
# 2. https://machinelearningmastery.com/dropout-regularization-deep-learning-models-keras/#:~:text=Dropout%20is%20a%20technique%20where,neuron%20on%20the%20backward%20pass.

# %% [raw]
# Q. what problem does dropout ratio solved?
#
# the deep Neural network has different architechtures some times shallow some times very deep trying to generalize on the given dataset. but in this pursuit trying too hard to learn different features from the dataset. they also learn statistical noises. this may imporve the peroformace on the training dataset, but it will fail massively on testing dataset (unseen dataset). this is the phenomenon of OVERFITTING. To tackle this problem we have various regularisation techniques that penalise the weights of the network but this wasn’t enough.
#
# to Fix the overfitting problem, we have enssemble technique (Adaboost, RandomForest, XGBoost, Gradient Boost.) for classification as well asn regression and regularization (L1, L2) for regression problems. but this is more computationaly expensives, as well as this requires multiple models to be train and store. which over time becomes a huge challenge as the networks grow deeper.
#
# So this is where the dropout layer is usefull

# %% [markdown]
# ![SegmentLocal](https://hackernoon.imgix.net/images/QNBTOZ8CHSUXADIOeFQWR1lzsxA2-rm49g3zii.gif "segment")

# %% [raw]
# Dropout is a technique where randomly selected neurons are ignored during training. They are “dropped out” randomly. This means that their contribution to the activation of downstream neurons is temporally removed on the forward pass, and any weight updates are not applied to the neuron on the backward pass.
# OR
# it is a technique to drop a nuron from the neural network or ignore them during training
# some neurons are included in training process and rest are deactivated
#
# p value represents the ratio to drop the number of random neurons from the neral network

# %% [raw]
# 1. when the the neron is drop, there will no forword propagation process from that neuron, as well      as not weights updatation in backword propagation.

# %% [markdown]
# ## Vanishing Gradient
# https://medium.datadriveninvestor.com/vanishing-and-exploding-gradients-in-neural-networks-bddd4504e59c

# %% [raw]
# Gradient :-
# 	it is a derivative of loss functions with respective of weights, it is use to update the weights 	 to minimize the loss during the backpropagation
#
# Vanishing Gradient :-
# 	Vanishing gradient problem occures when the derivative or slope goes smaller and smaller during     the weight updataion in backwardpropagation.
#
#     When weights update is very small or exponential small, the training time takes too much longer,     and in the worst case, this may completely stop the neural network training.
#
#     This phenonmena occures when the due to consicutively use of sigmoid and tanh activation             fuction. because the deriavtive range and output range of sigmoid is 0 to 0.25 and 0 to 1.           however the deriavtive range and output range of Tanh is 0 to 1 and -1 to 1 respectively.
#     Therefore, the updated weight values are small, and the new weight values are very similar to       the old weight values. this lead to the vanishing gradient problem, this problem can be overcome     by using ReLU activation function because the gradient is 0 for negatives and zero input, and 1     for positive input..

# %% [markdown]
# ## Exploding Gradient
# https://machinelearningmastery.com/exploding-gradients-in-neural-networks/

# %% [raw]
# Exploding gradient occurs when the derivatives or slope will get larger and larger as we go backward with every layer during backpropagation. This situation is the exact opposite of the vanishing gradients.
#
# This problem happens because of weights, not because of the activation function. Due to high weight values, the derivatives will also higher so that the new weight varies a lot to the older weight, and the gradient will never converge. So it may result in oscillating around minima and never come to a global minima point.

# %% [markdown]
# ### Solving vanishing and Exploding Gradient Problms
# https://www.analyticsvidhya.com/blog/2021/06/the-challenge-of-vanishing-exploding-gradients-in-deep-neural-networks/
