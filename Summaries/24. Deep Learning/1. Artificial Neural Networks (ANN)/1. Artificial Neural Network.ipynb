# %% [markdown]
# ## Neural Networks

# %% [markdown]
# https://towardsdatascience.com/a-gentle-introduction-to-neural-networks-series-part-1-2b90b87795bc

# %% [markdown]
# https://towardsdatascience.com/loss-functions-and-their-use-in-neural-networks-a470e703f1e9#:~:text=A%20loss%20function%20is%20a,the%20predicted%20and%20target%20outputs.

# %% [markdown]
# https://www.v7labs.com/blog/neural-network-architectures-guide

# %% [raw]
# - it is a functional unit of deep learning and are known to mimic the human brains that can solve complex data driven problems.
# - Input data associated with weights is process through different layers of the artifial neurons stackes togehter to produce desirable outputs.

# %% [markdown]
# # Architechtures in Neural Network

# %% [raw]
# - 1. Artificial Neural Network (ANN)
# 	:- Eg. works on tabular data
#
# - 2. Convolutional Neural Network (CNN)
# 	:- Eg. Works on Image and video data :- this algorithm for computer vision
#
# - 3. Recurrent Neural Network (RNN) :- Time Series Ananlysis
#  	:- Eg. Works on 1. Text Generation (google translate, youtube search bar (Text suggetions). )
#     				2. Climat forecasting
#                     3. Stock price prediction
#
# - 4. Generative Adversarial Network (GAN)
# 			- 1. creation
#             - 2. Detection (Fake or Real)

# %% [raw]
# The Neural Network architecture is made of individual units called neurons that mimic the biological behavior of the brain
#
# Artificial neurons or perceptron consist of:
#
# 1. Input
# 2. Weight
# 3. Bias
# 4. Activation Function
# 5. Output

# %% [markdown]
# ## Perceptron

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# To begin with x1, x2, x3 ... Xn are the inputs features and each features are  associated with weights, which helps to neural netwoork  to decide which feature is important. then they ared transfered to linear functions which is simillar to regression line (Y = Mx + C),
# 	here Y = X1W1 + X2W2 + Bias
#          where,            Y = prediction
#          		 slope     M = W1 weights
#                  intercept C = b Bais

# %% [raw]
# Input :-
# 	It is a set of features that are fed into the model for learning process.
#
# Weights :-
# 	each inputs are pass associated with its randomly assiged weights, Its main function is to give     importance to those features that contribute more towards the learning. It does so by               introducing scalar multiplication between the input value and the weight matrix.
#     	W1X1 + W2X2+...WnXn
#     justifying the importance of the feature with respect to its weights
#
# Transfer function -
# 	The job of the transfer function is to combine multiple inputs into one output value so that the     activation function can be applied. It is done by a simple summation of all the inputs to the       transfer function.
#     	Sum(W1X1 + W2X2+...WnXn)
#
# Activation Functions -
# 	It defines the output of the given inputs or a set of inputs. this is a Non-Linear Function, and     the the output will 0 or 1 depending on the input.
#
# 4. Bias :-
# 	  Bias is just like a intercept (b) added in a liner equation
#       	Y = Mx+ b
#       The role of bias is to shift the value produced by the activation function. Its role is 			  similar to the role of a constant in a linear function.
#
#       for ex. if X = 0 then value of b will be y
#       x = 0, w = 5, bias = 5
#       y = 5*0 + 5
#       y = 5

# %% [markdown]
# ######  in Perceptron neuron was able to classify linearly separable data but unable to classify Non-linearly separable data. it was able to classify datapoints on AND and OR gate because the datapoints were linearlly separable data but, it fails to classify the datapoints on XOR gate because it was non linearly separable data

# %% [markdown]
# ## 1. Artificial Neural Network (ANN)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# As the Hidden Layer increases, complexity of model increases

# %% [raw]
# 1. Input Nodes (Input Layers) :-
# 	  No Computation is Done here, they just pass the information to the next layer (To hidden             layers most of the time).
#       Ex. whatever human brain is seeing through there eyes, that information getting transfer             to the next neuron (means to the brain)
#
# 2. Hidden Nodes (Hidden Layers) :-
#       Hidden layers is the layer where intermediate processing or computation is done. they do 			  some computation then transfer the weights (Signals or information) from the input layer 			  to another hidden or output layers. There can be multiple hidden layers interconnected 	           to each others.
#
# 3. Output Nodes (output layer):
# 	  Here we finally use an activation function that maps to the desired output format

# %% [markdown]
# ## Working of Neurol Network

# %% [markdown]
# ### 1.  Forward Propagation

# %% [raw]
# Input layer work :-
#     Input layers recieves the data or information in the form of features and each inputs assigned a     weights and passed it to the Hidden layers there could be one or more than one hidden layers         according to the requirements. these hidden layers does all the back-end conputation process.
#
# Hidden layers :-
# 	In Hidden layer, all the data and it's associated weights which are recived from the input           stage, there will be two steps,
#     Step 1:- on this information the hidden layers will take the sumation of product of input                    and weights  plus Bias y = Sum(X1W1 + X2W2 + X3W3 ...XnWn + Bias) this equation is 				 look somthing like linear regression (Y = M1X1 + M2X2 ... MnXn)
#     		 Where, X1, X2...Xn = input features
#                 	   W1, W2...Wn = Weights associated with the inputes
#                        Bias        = Intercept (C)
#     Step 2:- the input with the higher weights and y will pass through the activation function
#     		 Equation of activation is  1 / 1 + e^(1-y)
#              This equation is also known as sigmoid (Logistic regression) and this equation will                  tranform the output between 0 and 1. if the value is less than threshold value (0.5)                then the point will classify to 0 means the neuron will not be activate but if the                  value if greater than 0.5 then the class will be 1 an neuron will be activate.

# %% [markdown]
# ## Activation Function
# https://www.v7labs.com/blog/neural-networks-activation-functions

# %% [raw]
# Activation Function is a Function which decides weather the neuron should be activated or not.
# it means this fucntion will decide weather the neuron's input to the nework is important or not in the process of prediction using simpler mathematical operations.
# the ouput of the Activation Function will always be between 0 and 1.
#
# The purpose of the activation function is to add non-linearity to the neural Network.
#
# if the value is less than threshold value 0.5, that is 0 that means the neuron is not activated.
# if the value is greater than threshold value 0.5, that is 1 that means the neuron is activated.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Loss Function

# %% [raw]
# The Loss Function is a function which compaires the target output and the predicted output values. measures how well the neural network models training the data. when trainig we aim to minimize the loss between the target and the predicted output .
#
# loss function is Sum(Yact - Ypred) / m

# %% [markdown]
# ### Gradient Descent Algorithm

# %% [raw]
# Gradient Descent Algorithm helps us to reduce the loss function. and helps us to get new W and b values
#
# W(new) = W(old) - α * d(L)/ d(W(old))
#
# b(new) = b(old) - α * d(L)/ d(b(old))
#
#         W(new) = new weights
#         b(new) = new bias
#         α = learning rate == 0.01
#         L = Loss Function
#
#         d(L)/ d(W(old)) = Slop
#         d(L)/ d(b(old)) = Slop

# %% [markdown]
# ### 2. Back Propagation
# - https://www.edureka.co/blog/backpropagation/
# - https://medium.com/edureka/backpropagation-bd2cf8fdde81

# %% [raw]
# Each input is loaded into the neural network in a process called forward propagation, and once the model has produced an output, then this predicted output (Ypredictd) is then compaired against the given target output (Yactual). this process is known as Backword Propagation.
# the hyperparameters of the model are then adjusted so that it now outputs a result closer to the target output.
#
# This is where loss functions come in.
# Now With the help of the Gradient Descent we can update the values of M and C.
#
# W(new) = W(old) - α * d(L)/ d(W(old))
#
# b(new) = b(old) - α * d(L)/ d(b(old))
