# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Activation Functions
# https://www.analyticsvidhya.com/blog/2021/04/activation-functions-and-their-derivatives-a-quick-complete-guide/

# %% [raw]
# It decieds weather the neuron should be activate or not. it means, it decieds weather the neuron's inpute is important or not in the process of predicting output using simplar operations.
#
# The Purpose of the Activation function is to add non-Linearity into the  Neural network input features.

# %% [markdown]
# #### Types of Activation Function

# %% [raw]
# 1. Linear Activation Function
# 	-1. Regression problem
#
# 2. Non-Linear Activation Function
# 	1. Classifiacation problem
#     	- 1. Binary classification
#         - 2. Multiclass Classifiacation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Linear Activation Function

# %% [raw]
# linear activation function is also known as stright line function, where the activation is proportional to input feature i.e. the weighted sum from neurons. it is also known as No activity function or identity functions
#
# f(x) = ax + c
#
# The problem with using Linear Activation function is that it can not defined in a specific range. Applying this function in all the nodes makes the activation function work like linear regression
# Another issue is the gradient descent when differentiation is done, it has a constant output which is not good because during backpropagation the rate of change of error is constant that can ruin the output and the logic of backpropagation.
#
# Linear Activation Function can be use at the end layer of the NN,
# we never use this function in hidden layers
#
# f(x) = x
# suppose the input is 1000 then the output will also be 1000
# f(1000) = 1000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Sigmoid

# %% [raw]
# Sigmoid Fucntion :-
#     Sigmod function is a type of activation function. it adds non-linearity into the inputs passed       to the neural networks.
#
# it is a layer specific fucntionm, and has a smooth curvature
# we can use this function in hidden layers
# it is use for binary classification problem in a output layer
#
# Formula
# 	sigmoid = 1 / 1 + e^-y
#
# - Graph is ranges between   = - inf to inf
# - Ouput ranges between      = 0 to 1
# - Derivative ranges between = 0 ot 0.25
#
# - Calculations are expensives

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
#  Problem with Sigmoid Function.
# 	When we use the Sigmoid function consecutivlly, it faces the vanishing gradient problem

# %% [markdown]
# ### 2. Tanh (Hyperbolic Tangent) activation function

# %% [raw]
# this function also known as Zero Centric fucntion because it passes through origin, this fucntion is similar to the sigmoid fuctnion where the ouput of sigmoid ranges between 0 and 1, where as the output of Tanh will be between -1 to 1.
#
# it is only used in hidden layer
#
# Formula -
# 	e^z - e^-z / e^z + e^-z
#
# - Graph is ranges between   = - inf to inf
# - Ouput ranges between      = -1 to 1
# - Derivative ranges between = 0 to 1
#
# - Calculations are expensives

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# Problem with Tanh
# 	When we use the Tanh function or hyperbolic function consecutivlly, it faces the vanishing           gradient problem
#
# Vanishing Gradient probelm arrises because at the time of updating the weights and biases, the derivative of the loss becomes infinitly small.
#
# for example tanh derivative ranges between 0 to 1, so if we are using tanh acitvation fuctnion consecutively (one after one tanh) the derivative will always be between 0 and 1 and that derivative will go infinilty smaller (e.g 0.0000025).

# %% [raw]
# - Parameters of Higher lavel changes significantly
# - Changes in lower layer is miniscule
# - we can see the mistakes or the performace of the Activations by Stagnation in learning
# - It stop the performance of the algorithm

# %% [markdown]
# ### 3. RELU
# #### (Rectified Linear Unit)

# %% [raw]
# it provides the same benifits as the sigmoid fucntion, but unlike sigmode function it resolves the Vanishing Gradient problem.
# Formula :
# 	Max(y,0)
#
# - input range = -inf to inf
# - Output = Max(0,z)
# - Derivative = die out
#
# for example,
# 	max(0,2) = 2
#     max(0,3) = 3
#     max(0,-2) = 0
#     max(0,-3) =0

# %% [markdown]
# ![image.png](attachment:image.png)#

# %% [raw]
# Unfortunatly, It was the perfect fit for the intermidiate layers, it is mostly used in hidden layers
#
# - z > 0 then ouput is 1
# - z < 0 then output is 0
# Problem with RELU
# 	Dying RELU problem.
#     Once the Neuron is dead then it is forever dead, when most of the neurons returns output 0           (z<0). gradient fails to flow during back propagation. ultimately large part of the NN becomes       inactive
# reasons
# 1. High learning rate
# 2. High -ve bias

# %% [markdown]
# ### 4. Leaky Relu

# %% [raw]
# Leaky Relu is the varient of RELU, it resoves the problem with ReLU whcih is Dying gradient, instead of being 0 when Z < 0. leaky ReLU allows a small, non-zero, constant gradient α (normally, α=0.01), Leaky ReLUs attempt to fix the “dying ReLU” problem.
#
# because it has provided small positive leak as slope, left half negative axis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. P_ReLu
# #### Parametric Relu

# %% [raw]
# This is a another varient of RELU axis to solve the problem of dead neron as gradient becomming zero.
# PReLU gives the neurons the ability to choose what slope is best in the negative region. They can become ReLU or leaky ReLU with certain values of α.
# - α wis dynamic learning rate
# - if α <= 0 f becomes ReLU
# - α > 0, f becomes leaky ReLU
# - if α is a learnable parameter, f becomes PReLU.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # ELU (Exponential Linear Unit) Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Elu is proposed to solve the problem with ReLU. obviouly ELU has all the advantages of ReLU, and
#
# - Bi Dead ReLU issues
# - The mean of the output is close to 0, zero-centered
# One small problem is that, it is slightly more computationally intensive, simillar to leaky ReLU , although theoretically better the ReLU, there is currently no good evidence is practive the ELU is always better than ReLU

# %% [markdown]
# # SoftMax
# https://www.analyticsvidhya.com/blog/2021/04/introduction-to-softmax-for-neural-network/

# %% [raw]
# this function is use for multiclass classification problem.
# this function is used in the output layer of neral network, and the output layer neral network is depends on the total number of classes we have, for example if we have 3 classes in target column then there will be 3 output neurons in the ouput layer.
#
# The Softmax activation function calculates the relative probabilities.
#
# here, X represents the values from the neuron of the output layer. Later these values are divided by the sum of exponential values in order to normalize and then convert them into probabilities.
#
# Note that, when the number of classes is two, it becomes the same as the sigmoid activation function. In other words, sigmoid is simply a variant of the Softmax function.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Suppose the value of Z21, Z22, Z23 comes out to be 2.33, -1.46, and 0.56 respectively. Now the SoftMax activation function is applied to each of these neurons and the following values are generated.
# These are the probability values that a data point belonging to the respective classes. Note that, the sum of the probabilities, in this case, is equal to 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Swish (A Salf gated function)

# %% [raw]
# this swish activation fuction is by google.
#
# f(x) = x *sigmoid (x)
#
# NOTE :- we can only use this function whenever we have Neurol networks greatter than 40. layers
#
# Example :- This function is use for image classification problem
