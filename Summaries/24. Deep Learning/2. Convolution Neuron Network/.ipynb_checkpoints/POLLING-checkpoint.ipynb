# %% [markdown]
# https://www.deeplearning.ai/ai-notes/initialization/index.html

# %% [raw]
# Image (filter) convolution >> feature map >> polling >> convolution >> polling >> flattened_layer >> prediction

# %% [raw]
# on top of that convolution layer we apply ReLU, Rectified Liner Unit fuction to remove any linearity or increase the non-linearity in our images.

# %% [raw]
# Why ther is a need to use CNN, when ANN  was doing good job with complex data?
#
# so The answer is that, ANN's architechture needs input as a features. there are Three layers in ANN
# 1. input - this where the features are passe
# 2. Hidden Layer - in this layer inputs are multiplied  with its respect to weights and sum the                         direct it to the activation function.
# 3. Ouput layer :- this is the layer where we get the final output of the neuron
#
#
# And this multilayer perceptron model will do good job in Numerical/Categorical data, But when this comes to image data. We features/inputs of NN become the pixel values. so the model will read the pixels values and do feature extraction and classification.
#
# but if we look deeper the pixels are just not the values but but the relation between pixels or in other words features are the edges, lines, corners or basically the shapes and patterns of an image.
#
# So, in CNN we are adding another layer to the multilayer perceptron, there fore it is known as Convolutional neural network.
#
# The Purpose of this Convolutional layer is that it extracts the features from the image and convert it into single vectore. after that ANN will come into the picture.

# %% [markdown]
# # Layers in CNN

# %% [raw]
# There are five different layers in CNN
#
# 1. Input layer
# 2. Convo layer (Convo + ReLU)
# 3. Pooling layer
# 4. Fully connected(FC) layer
# 5. Softmax/logistic layer
# 6. Output layerr

# %% [markdown]
# ## 1. Pooling layer
# https://adamharley.com/nn_vis/cnn/2d.html

# %% [raw]
# Pooling is the abother building block of the CNN.
# Pooling layer is used to reduce the Special invariace in our input image after convolution. if we are using fully connected layer after convo layer, then it would be computationaly expencive, there fore we use pooling. This is also useful for extracting dominant features which are rotational and positional invariant, thus maintaining the process of effectively training the model.

# %% [raw]
# Special invariace in our input image :-
#     meaning the images might be the same, but the organization could be different such as if something tilts, or twists, or is bit different to the ideal scenario, then we can still pick up the feature plus pooling significantly reduces the size of our images, also pooling helps with avoiding any kind of overfitting of our data or of our model to the data. At the same time pooling preserves te main feature that we're after.

# %% [markdown]
# ### There are Four Types of Pooling
# - Min
# - Max
# - SUm
# - Average

# %% [raw]
# 1. Minimum pooling :- Returns the minimum value from the portion covered by the Kernel.
#
# 2. Maximum pooling :- Returns the Maximum value from the portion coverd by the kernel
#
# 3. Sum pooling :- return the sum of all the element from the portion coverd by the kernel
#
# 4. Average :- return the average of all the element from the portion coverd by the kernel

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Flattened

# %% [raw]
# now the pooled features from the pooling layers are then flattened, meaning all the values will be converted into single vector. i.e matrix size of pooled vector 2 X 2 = 4 will convert ot 4 x 1.
#
# for example, in fig maximum poolling,
# 	the flatten vector would be [20,30,112,37]
#
# Now this flatten vector will be passed to the neural Fully connected network (FC),

# %% [markdown]
# ### Fully connected Network (FC)

# %% [raw]
# Fully connected layer involves weights, biases, and neurons. It connects neurons in one layer to neurons in another layer. It is used to classify images between different category by training.
# FC is similar to ANN. which takes the input as a flatten vector and passed it to the next neural network. and at the end it will produce the classification of object

# %% [markdown]
# ## Data Aggumentation
# https://nnart.org/what-is-data-augmentation-in-a-cnn/#:~:text=Data%20augmentation%20is%20the%20addition,model%20robust%20with%20better%20performance.

# %% [raw]
# Data augmentation is the addition of new data artificially derived from existing training data. Techniques include resizing, flipping, rotating, cropping, padding, etc. It helps to address issues like overfitting and data scarcity, and it makes the model robust with better performance.

# %% [markdown]
# - Data preprocessing library :-
#     https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Weight initialization
# - https://towardsdatascience.com/weight-initialization-techniques-in-neural-networks-26c649eb3b78
# - https://machinelearningmastery.com/weight-initialization-for-deep-learning-neural-networks/
