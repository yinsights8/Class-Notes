# %% [markdown]
# # CNN
# 1. https://www.analyticsvidhya.com/blog/2021/05/convolutional-neural-networks-cnn/
# 2. https://towardsdatascience.com/covolutional-neural-network-cb0883dd6529
# 3. https://sarathpanat.medium.com/all-about-convolutional-neural-network-cnn-6ccce6738958

# %% [markdown]
# # Layers in CNN

# %%
There are five different layers in CNN

Input layer
Convo layer (Convo + ReLU)
Pooling layer
Fully connected(FC) layer
Softmax/logistic layer
Output layer

# %% [raw]
# CNN or Convolutional Neural Network is a type of Artificial Intiligence (AI), which is widely use for image / object recognation and classification.
#
# Convolution :- in mathematics convolution is a mathematical operation on two functions that produces a third function that expresses how the shape of one is modified by the other.

# %% [raw]
# Application
#    1. image processing
#    2. blur image
#    3. sharpen image
#    4. enhance image
#    5. object detection

# %% [markdown]
# ## Image Representation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Each image provide information of the colors, each colored image is a combination of the colors which are RED, GREEN, BLUE, known as Channels. Images are encoded into color channels, the image data is represented into each color intensity in a color channel at a given point, the most common one being RGB, which means Red, Blue and Green. The information contained into an image is the intensity of each channel color into the width and height of the image, just like this

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# >> right hand side = show in squares, are pixels
# >> left hand side = each pixels contains some values
#
# Now in the above image we can see, a pixels has its own logical address in the form of number. and those numbers are representing the intensity of color [0-255]. above image is in GrayScale image.
# image person  = abrahim lincon
#
# An Image is just a matrix of numbers. and each pixel has its own logical address
#
# Pixel Is a square element of an image, it contain some values. and the values are ranges between 0 to 255 (size of pixels = 8 bit). and these pixel values are stored in the form of numpy array.
#
# '0'   represents absence of light (Dark, Black)
# '255' represents presence of light (white)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### grayscale image

# %% [raw]
# Back in time before color TV's was introduced, there used to be black & white TV's. which uses grayscale imges. means it was representing the picture in black & white color. that color was the combination of black (0) and white (255).
#
# GrayScale image has only one channel

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## RGB colors

# %% [raw]
# it contains mainly all the colors and can be generated by using THREE Primary colors.
#
# RGB colors consists of THREE Channels
# R = Red
# G = Green
# B = Blue
#
# all the matrices will have 0 to 255 range pixel values. finally all the matrices are superimposed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Convolution
# https://deeplizard.com/resource/pavq7noze2

# %% [raw]
# convolution is a mathematical operations between matrices. (imput and the filter matrices)
#
# The filter (green) [3 x 3] slides over the input image (blue) [5 x 5] one pixel at a time starting from top left.
#
# The filter (Green) multiplies its own values with overlaping values of the input image while sliding over it and adds all of them up to output of singel values for each overlap.
#
# And this output matrix (red) is our result matrix of convolution operation.

# %% [markdown]
# - fig --> 1
# ![SegmentLocal](https://miro.medium.com/max/828/0*PamiOyIWSHsaz-OX)

# %% [raw]
# If we have N x N image size and F x F filter size then after convolution result will be
#
#         N - F + 1 = FM
#         where, N = dimentions of features
#                F = dimentsion of filter
#                FM = Feature map (result of IMAGE and FILTER)

# %% [markdown]
# # Filter
# https://docs.gimp.org/2.6/en/plug-in-convmatrix.html

# %% [raw]
# Every image has vertical and horizontal edges which combining to form a image convolution operation is use with some FILTERS for detecting edges. for example we have a gray scale image with dimentsion of 6x6, and a filter with dimentions of 3x3. when the 6x6 image convols with 3 x 3 filter we will get 4x4 feature map.
#
# convols, means 3x3 filter will contains some random values which is actually the weights (W) with a specific range. then  3 x 3 filter matrix get multiplied with 3 x 3 size of our grey scale image adding bias to each pixels (z=Wx+bias). then we shift one column right up to end , after that we shift one row and so on.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# In RGB there will be muliple types of filter and these filter will be parallely applied to the images. as we can see in the bellow gif.
#
# Here’s a 6 by 6 by 3 image, and a 3 by 3 by 3 filter once again shown on figure. Notice that the 3 by 3 by 3 filter has 27 numbers, or 27 parameters, that’s three cubes.

# %% [markdown]
# ![SegmentScale](https://miro.medium.com/max/828/1*hGyDx8VKYPnJqIoCidLzFw.gif)

# %% [markdown]
# # Padding

# %% [raw]
# There are two types of paddings
# 1. valid padding
# 	Valid paddings means no padding is applid to the input image
# 2. Same padding
# 	it implies that addig a layer of a padding to input image, so that ouput size of the image           remains the same

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# padding is simply a process of adding extra layer in the input image.
# Basically padding is a additional border to input image for solving two problems.
#
# 1. Shrinking outputs
# 2. Losing information on corners of the image.

# %% [raw]
# Valid padding :-

# %% [markdown]
# ![SegmentLocal](https://miro.medium.com/max/1400/1*g0OmDI1w9KqN7Rpw6Qo8Xg@2x.gif)

# %%
def loss(N=None,F=None,p=0):
    """
    n= size of image, n = int,
    f = filter size, f = int
    fm = feature map size
    """
    f_map = (N + 2*p - F + 1) 
    loss = (N*N) - (f_map*f_map)
    print(f"Size of image (pixels):- {N} x {N}\nFilter size = {F} x {F}")
    print("Feature map shape :- ",f_map, "x", f_map)
    print("Loss of pixels :- ",loss )    

before_pad(N=5,F=3)
# Out:
# Size of image (pixels):- 5 x 5
# Filter size = 3 x 3
# Feature map shape :-  3 x 3
# Loss of pixels :-  16

# %%
Same Padding :-

# %% [raw]
# We can observe that the size of output is smaller that input. To maintain the dimension of output as in input , we use padding. we can also see that there is a loss of the pixels that we are getting if we are not using the padding.
#
# Adding padding to an image processed by a CNN allows for more accurate analysis of images

# %% [markdown]
# ![SegmentLocal](https://miro.medium.com/max/1400/1*17TNPi4m0pBqOCGrXzU27w.gif)

# %%
def loss(N=None,F=None,p=0):
    """
    n= size of image, n = int,
    f = filter size, f = int
    fm = feature map size
    """
    f_map = (N + 2*p - F + 1) 
    loss = (N*N) - (f_map*f_map)
    print(f"Size of image (pixels):- {N} x {N}\nFilter size = {F} x {F}")
    print("Feature map shape :- ",f_map, "x", f_map)
    print("Loss of pixels :- ",loss )    

before_pad(N=5,F=3,p=1)
# Out:
# Size of image (pixels):- 5 x 5
# Filter size = 3 x 3
# Feature map shape :-  5 x 5
# Loss of pixels :-  0

# %% [raw]
# Now observe that after addining padding to the input we are not lossing any information of pixels from the inputs, especially from the cornors of the image. and also the dimentions are maintained.
#
# After applying padding
#
# As we know that after applying padding we will get the same dimension as original input dimension
# (N x N). Hence we have,
#
# 	 N + 2p - F + 1 = FM
#      where, N = dimentions of features
#             F = dimentsion of filter
#             p = padding
#             FM = Feature map (result of IMAGE and FILTER)

# %% [markdown]
# ![SegmentLocal](https://miro.medium.com/max/828/0*jSYji1D43vJWZZ_5)

# %% [markdown]
# ### Strides

# %% [raw]
# Stride is the number of pixels shifts over the input matrix. When the stride is 1 then we move the filters to 1 pixel at a time. When the stride is 2 then we move the filters to 2 pixels at a time and so on. The above figure shows convolution would work with a stride of 2.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
