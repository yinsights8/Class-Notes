# %% [markdown]
# - KNN explained:-
#
# https://towardsdatascience.com/machine-learning-basics-with-the-k-nearest-neighbors-algorithm-6a6e71d01761

# %% [raw]
# - KNN is the supervised machine learning algorithm which is use to solve classification as well as regression problems.
#
# 1. K-Nearest Neighbor is a Supervised machine Learning Algorithm.
# 2. It is useful for both Classification as well as Regression
# 3. K - Nearest Neighbor is a Distance based Algorithm. That means, We need to calculate the Distances
# 4. We do calculate the distances between data points by using distance metrics.
# 5. KNN algorithm is a Non-Parametric Algorithm
# 6. KNN is Non Parametric Algorithm That means, We do not have an assumptions on the data.
#
# 7. KNN is also called as Lazy Learner Algorithm

# %% [markdown]
# ## KNN Algorithm

# %% [raw]
# 1. In KNN Algorithm we need to find out the best K Value (K - Nearest Neighbors)
# 2. We need to calculate the distances between new datapoints (Testing Data points/Unseen Data) with all the remaining data points. (Training Data Points)
# 3. In KNN Algorithm default value of is (K = 5)
#
# k = 5
# k < 5 >> data can be Noisy, (Low Bias and High Variance)

# %% [markdown]
# ## Feature scalling
# 1. MinMax Scaler (Normalization)
# 2. Stanard Scaler (Standardization) >> Z - Score
# 3. Robust Scaler
# 4. Unit Vector Scaler
# 5. Power Transform Scaler

# %% [raw]
# Feature Scaling :
#
#     Feature Scaling is used to scale down the Numeric Features in to the same scale.
#
#     Model Is not able to understand the Units, SO that we need to use Feature Scaling on Scale Variant Data.
#
#     Like Unit : KM, M, Years in Numbers, Days

# %% [markdown]
# ### 1. Normalization (MinMaxScaler)

# %% [raw]
# Normalization :
#
#         In Normalization we can rescale the features in a specific range (0 to 1)
#
#         Xnor = (X - Xmin)/(Xmax - Xmin)
#
#         If the data is not following Guassian Distribution then we can use Normalization
#
#         Do not use Normalization on One hot Encoding Features and Target Variable

# %% [markdown]
# ## Standard Scaler (Standardization) >> Z Score

# %% [raw]
# Standardization :
#
#         standardization is use to rescale the features based on the standard normal distribution, (mean = 0 and std = 1)
#
#         we do not have any specific range for the to rescale the features, it will be between (-inf to +inf and -3 to +3 std)
#
#         Xnew = (X - Xmean) / (STD)
#
#         If tne data is Following Gaussian Distribution then we can use Standardization
#
#         Do not use Standardization on One Hot Encoding Features and Target Features.

# %% [markdown]
# ### Where to use feature scalling

# %% [raw]
# - 1. K - Mean uses the Euclidean distance measure here feature scalling matters
# - 2. k - Nearest neighbours
# - 3. Principle component analysis (PCA) :- tries to get the features with maximum variance, here too feature scalling is required
#
# - 4. Gradient Descent :- Calculation speed increases as theta calculation becomes faster after feature scalling
#          - Ex. 1. Linear regression
#
#
# NOTE :- naive bayes, Linear Discriminant analysis and tree based models are not affected by feature scalling, in short any algorithm which is not distance based is not affected by feature scalling.

# %% [markdown]
# ## Distance matrices

# %% [raw]
# - 1. Euclidean Distance *
# - 2. Manhattan Distance *
# - 3. Minkowski Distance *
# - 4. Chebyshev distance
# - 5. hamming distance
# - 6. Cosine Similarity
# - 7. Jaccard Similarity

# %% [markdown]
# Distance metrices :-
#     https://medium.com/geekculture/7-important-distance-metrics-every-data-scientist-should-know-11e1b0b2ebe3#:~:text=Euclidean%20Distance,-Euclidean%20Distance%20is&text=Mathematically%20it%20is%20the%20square,between%20two%20different%20data%20points.&text=Most%20Machine%20learning%20algorithms%20including,two%20data%20points%20or%20observations.

# %% [markdown]
# ### 1. Euclidean Distance
#  - P = 2
#  - E.D < M.D

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [raw]
# - it is also known as the L2 Norm vector
# - it is the square root of sum of differences between two different data points
# - Most Machine learning algorithms including K- Means Clustering uses Euclidean distance in order to calculate the similarity between two data points or observations.
#
# - Moreover, Euclidean distance is used when we are calculating the distance between two sets of data that have numerical data type i.e.integer or float.
#
# Equation :-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### NOTE :- Point to keep in mind that if your data have features with different scales it is a must to normalize or standardize the features across all columns before calculation of Euclidean distance. If scaling of features is not performed then large values in features will dominate the distance metrics.

# %% [markdown]
# ### 2. Manhattan Distance
# P = 1
# M.D > E.D

# %% [raw]
# - Also called as the city block distance or L1 norm of a vector.
# - Manhattan distance is calculated as the sum of absolute distances between two points.
#
# - it calculates the differences of Adjecent sides.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Mostly it is recommended to use Manhattan distance instead of Euclidean distance when we have real value vectors in integer dimensional space.

# %% [markdown]
# ######  NOTE :- Manhattan Distance is always gretter than Euclidean distance

# %% [markdown]
# - Distance metrices :-
# - https://aiaspirant.com/distance-similarity-measures-in-machine-learning/

# %% [markdown]
# ### 3. Minkowski Distance

# %% [raw]
# - Minkowski Distance generalizes Euclidean and Manhattan Distance.
# - It is also called p-norm vector as it adds a parameter called the “p” that allows different distance measures to be calculated
#
# For Different values of p Minkowski will be-
#
# p=1, the distance measure is the Manhattan measure.
# p=2, the distance measure is the Euclidean measure.
# p = ∞, the distance measure is the Chebyshev measure

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# When we are implementing any Machine learning Algorithm that uses Minkowski as a distance measure we can tune the hyperparameter “p”.

# %% [markdown]
# ### KNN Classification

# %% [raw]
# - 1. load the Data
#
# - 2. Initialise the value of K (K - number of nearest negihbours)
#
# - 3. For Each example in a data
#      - 3.1 we need to calculate the distances of the testing data with remaining training data points
#      - 3.2 then sort the distances in an ascending order.
#
# - 4. pick the first k entries of the sorted collection
#
# - 5. then get the lables of the selected entries
#
# - 6. In Classification,
#     - 6.1 case 1 :- data points will be classify on voting the points
#     - Rear Cases
#         - 6.2 case 2 :- if the distances are same from both the classes but one class has maximum                            data points as compair to another class data pionts, in that case the unseen data will classify on the basis of whichever class has maximum data points.
#
#         - 6.3 Case 3 :- if the distances as well as selected points are same, in this case the data point will be classify on which ever the class has 0 assigned while replacing the descrete value 0 and 1.

# %% [markdown]
# ### KNN Regression

# %% [raw]
# - 1. load the Data
#
# - 2. Initialise the value of K (K - number of nearest negihbours)
#
# - 3. For Each example in a data
#      - 3.1 we need to calculate the distances of the testing data with remaining training data points
#      - 3.2 then sort the distances in an ascending order.
#
# - 4. pick the first k entries of the sorted collection
#
# - 5. then get the lables of the selected entries
#
# - 6. In regression, KNN will calculate the average or mean of the k-entries
#
# - 7. that average value would our predicted value of the model.

# %% [markdown]
# ### HyperParameters to find the best K  - value

# %% [raw]
# - 1. GridSearchCV
#     - in GridSearchCV, the data points are devided into equal number of datassets. each datasets are stored into a containers. then each single container are compaired itself with other remaining       containers. on whichever containers has good or higher accuracy that would be our K - Value in       KNN.
#
#      here, we are breaking the datasets into equal parts then the GridSearchCV will compairs the accurices of the each container with remaining containers, whichever the GridSearchCV
#      considers the good accuracy or High accuracy that would be our K-Value in KNN
#
# Ex: - suppose we have 1000 records in a dataset, out of 1000 we pass CV = 5, that means there will be five containers with 100 datasets in each containers, each 100 datasets will be compairs with another remaining containers and trains the model on it. which ever container finds the best accuracy on that points GridSearch CV suggest the which parameters should we consider to tain our model
#
# NOTE :- It is recommonded that use GridSearchCV whenever ther is a small datasets.
#      Ex:- datasets with 1000 - 10000,20000 recoreds

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# - 2. RandomizeSearchCV
#     - RandomizeSearchCV works in the similar way as GridSearchCV. But the Only difference is that it       will select random combination from the datasets unlike GridSearchCV.

# %% [markdown]
# #### Advantages Of KNN

# %% [raw]
# - 1. KNN algorithm can solve both regression as well as classification problems
# - 2. it is a Non - Parametric algorithm (We do not have any assumption on data)
# - 3. Hyperparameter is required (which is K and P value)
# - 4. No training steps are required (Faster than the other algorithms)
# - 6. It will automatically lends to the multiclass classification

# %% [markdown]
# ### Disadvantages of KNN

# %% [raw]
# - 1. it is slow learner algorithms
# - 2. the algorithm get significantly slower as the number of examples or/predictors/ independent variables increases.
# - 3. suitable for small datasets
# - 4. sensitive to outliars
#
# # When we are having high dimensional datasets, In that case we can use dimensionality reduction
# techniques (PCA) ----->>> Principal Component Analysis
