# %% [markdown]
# ### Naive bayes :-
# 1. https://www.kdnuggets.com/2020/06/naive-bayes-algorithm-everything.html
# 2. https://www.javatpoint.com/machine-learning-naive-bayes-classifier

# %% [markdown]
# ### 1. If the variables contains categorical values

# %% [raw]
# - it is a supervised machine learning algorithm, and it is use to solve the classification problem
# - it is based on bayes theorem
# - it is mainly used for text classification that includes high dimentional training dataset
# - Naive bayes algorithm is probabilistic algorithm, which means it predicts on the basis of the probability of the object.
#
# - this algorithm is simplest and most effective classification algorithm which helps in building the   fast machine learning models which can make quick predictions.
# - for example spam filtration, sentimental analysis and classifying articals.

# %% [raw]
# -  Naive is the term in which we are having the Assumption.
#
# Naive  >> It assumes that, Features are mutually Independent. (Input)
#          it assumes that the occurance of certain features is independent on the occurace of other            features
#
# Bayes >>  It is called Bayes because it depends on the principle of Bayes' Theorem.

# %% [markdown]
# ## Bayes Theorem

# %% [raw]
# Bayes' theorem is also known as Bayes' Rule or Bayes' law, which is used to determine the probability of a hypothesis with prior knowledge. It depends on the conditional probability.
#
# The formula for Bayes' theorem is given as:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = independent variables
Y = target variable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Now, you can obtain the values for each by looking at the dataset and substitute them into the equation. For all entries in the dataset, the denominator does not change, it remains static. Therefore, the denominator can be removed and proportionality can be injected.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# P(A|B) >> can be read as Probability of A given to B.
# P(B|A) >> can be read as Probability of B given to A.
#
# P(A|B) - posterior probability :-  Probability of hypothesis A on the observed event B.
#
# P(B|A) - likelyhood probability :-  Probability of the evidence given that the probability of a                                         hypothesis is true.
#
# P(A) - prior probability or conditional probability :- Probability of hypothesis before observing                                                          the evidence.
#
# P(B) - Marginal probability or Evidence probability :- Probability of Evidence.

# %% [raw]
# posterior probability  = (likelyhood probability * prior probability) / marginal probability
#
# for yes,
# P(yes|{x1,x2,x3}) = ( P(x1|yes) * P(x2|yes) * P(x3|yes) * P(yes) ) / P(x1) * P(x2) * P(x3)
#
# for no,
# P(no|{x1,x2,x3}) = ( P(x1|no) * P(x2|no) * P(x3|no) * P(no) ) / P(x1) * P(x2) * P(x3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How naive bayes classifier works

# %% [raw]
# Step 1 :- Convert the given dataset into frequency tables.
# Step 2 :- Generate Likelihood table by finding the probabilities of given features.
# Step 3 :- Now, use Bayes theorem to calculate the posterior probability.

# %% [markdown]
# ### Types of Naive  bayes classifier

# %% [raw]
# 1. Gaussian: The Gaussian model assumes that features follow a normal distribution. This means if predictors take continuous values instead of discrete, then the model assumes that these values are sampled from the Gaussian distribution.
#
# 2. Multinomial: The Multinomial Naïve Bayes classifier is used when the data is multinomial distributed. It is primarily used for document classification problems, it means a particular document belongs to which category such as Sports, Politics, education, etc. The classifier uses the frequency of words for the predictors.
#
# 3. Bernoulli: The Bernoulli classifier works similar to the Multinomial classifier, but the predictor variables are the independent Booleans variables. Such as if a particular word is present or not in a document. This model is also famous for document classification tasks.

# %% [markdown]
# ### 2. If the Variables contains Contineous values

# %% [raw]
# Option 1 :- if the variables having contineous values in that case we have convert those values into             category.
#             that means we have to tranform nymerical the values to the categorical counterparts                 before creating there frequency table.
#
#
# Option 2 :- we can use distribution of the numerical variable to have a good guess of the frequency.            For example, one common method is to assume normal or gaussian distributions for                    numerical variables.

# %% [raw]
# The probability density function for the normal distribution is defined by two parameters (mean and standard deviation).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The likelihood of the features is assumed to be Gaussian, hence, conditional probability is given by:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Advantages and Disadvantages

# %% [raw]
# Advantages :-
#     1. it works on smaller datasets
#     2. it can handal larger datasets
#     3. it is use for binary as well as multiclass classification problems
#     4. it the most popular choice for text classification problem (we can consider NLP)
#     5. Hyperparameters are not required in naive bayes

# %% [raw]
# Disadvantages :-
#     1. Naive bayes assumes that all the feature are independent or unreleted, so it cannot learn the        relationship between the features.

# %% [markdown]
# ### Applications

# %% [raw]
# 1. credit scoring
# 2. medical data classification
# 3. real time predictions
# 4. spam filtering
# 5. sentiment analysis (the process of detecting positive or negative sentiment in text.)
