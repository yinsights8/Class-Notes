# %% [markdown]
# # - Random Forest
# https://www.analyticsvidhya.com/blog/2021/06/understanding-random-forest/

# %% [markdown]
# ## Ensemble Technique

# %% [raw]
# - Ensemble simply means combining multiple models. Thus a collection of models is used to make predictions rather than an individual model.

# %% [raw]
# - 1. Bagging– It creates a different training subset from sample training data with replacement & the final output is based on majority voting. For example,  Random Forest.
#
# - 2. Boosting– It combines weak learners into strong learners by training a models siquencially such that the final model has the highest accuracy. For example,  ADA BOOST, XG BOOST

# %% [markdown]
# ### Ensemble Technique Random Forest

# %% [raw]
# - 1. It is a Supervised Machine Learning Algorithm, it is usefull for classification as well as Regression problems.
# - 2. Random Forest uses the Bagging technique, it includes Bootstrap and Aggrigation.
# - 3. Random forest is a Ensemble Technique which tackles one of the biggest problem with Decision Tree which is VARIANCE (Low Bias, High Variance: Overfiting)
#
# - 4. One of the most important features of the Random Forest Algorithm is that it can handle the data set containing continuous variables as in the case of regression and categorical variables as in the case of classification. It performs better results for classification problems.

# %% [raw]
# 1. Bagging
#     - it is also known as BOOTSTRAP AGGRIGATION is a Ensembel technique use by random forest.
#     - It follows the Parallel sequence
#     - In Bagging, N-number of base learners or weak learners are created and each base learners contains random samples provided by the original data set with replacement known as row sampling and feature sampling.
#     - Key points is each base learner should contains data less than the original dataset. and these datasets won't contain any unique features and recoreds.
#     - after that Over Sampling will be done in order to complete the count of the data in a base learners.
#     - Now Each Model or base learner will be train independently which generates result.
#     - The final output is based on majority voting after combining the results of all models. This step which involves combining all the results and generating output based on majority voting is  known as aggregation.

# %% [raw]
# Steps involved in random forest algorithm:
#
# Step 1: In Random forest n number of random records are taken from the data set having k number of records.
#
# Step 2: Individual decision trees are constructed for each sample.
#
# Step 3: Each decision tree will generate an output.
#
# Step 4: Final output is considered based on Majority Voting or Averaging for Classification and regression respectively.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 1. Hard votting :- majority of the ouputs will be taken as a final output
# 2. Soft votting :-
# - Final result will be based on Hard Votting

# %% [raw]
# Types of Voting Criteria:
#
#     1. Soft Voting >> Prob
#     2. Hard Voting  >> Max Count
#
#      Class0  Class1
# M1 >> [0.4,  0.9]  >> Class1
# M2 >> [0.9,  0.8]  >> Class0
# M3 >> [0.5,  0.3]  >> Class0
#
# If we are performing Hard Voting here. Then what will be our predicted class?
# >>> Class 0  >> Because Maximun count which we are getting it from Class 0
#
# Hard Voting  >> Predicted Class >> Class 0
#
#
#      Class0  Class1
# M1 >> [0.44,  0.97]  >> Class1
# M2 >> [0.98,  0.99]  >> Class1
# M3 >> [0.54,  0.39]  >> Class0
#
# Soft Voting >> Predicted Class >> Class1
#
#      class0   class1
# M1 >> [0.55,  0.87]  >> Class1
# M2 >> [0.95,  0.89]  >> Class0
# M3 >> [0.58,  0.39]  >> Class0
#
# Soft Voting >> Predicted Class >> CLass 1

# %%
(0.55 + 0.95 + 0.58)/3
# Out:
# 0.6933333333333334

# %%
(0.87 + 0.89 + 0.39)/3 ## Soft Voting >> Predicted Class >> CLass 1
# Out:
# 0.7166666666666667

# %% [markdown]
# ## Dicision Tree And Random Forest

# %% [raw]
# - 1. Decision Tree :-
#         1. Decision Tree Suffers from overfitting condition, if we don't use the hyperparameters
#         2. single decision tree is Faster in computation
#         3. When a data set with features is taken as input by a decision tree it will formulate some set of rules to do prediction.

# %% [raw]
# - 2. Random Forest :-
#         1. Random forest is created by the subsets of data and the final ouput will be based on average or majority ranking and hence the problem of overfitting is taken care of.
#         2. computation is slower due to Multiple Decision trees
#         3. Random forest randomly selects observations, builds a decision tree and the average result is taken. It doesn’t use any set of formulas.

# %% [markdown]
# ## Advantages and Disadvantages

# %% [raw]
# Advantages :-
# - 1. RF is usefull for classification as well as Regression
# - 2. It is easy to understand and interprete, visualizing
# - 3. It reduces the Overfitting problem which is with Decision Tree

# %% [raw]
# Disadvantages :-
# - 1. RF trains multiple models independently, and build multple trees, therefore it causes much computational power
# - 2. Complexity will be high
