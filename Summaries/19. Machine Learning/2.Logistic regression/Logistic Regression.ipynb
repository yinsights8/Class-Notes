# %% [markdown]
# ## "Logistic Regression"

# %% [raw]
# 1. It is a supervised machine learning Algorithm which is use to resolve the classification problem.
# and it is use to predict the probability of the target variables.
#
# -  It is used when the data is linearly separable and the outcome is binary or dichotomous in nature.
#
# 2. Logistic Regression is a Probabilistic Algorithm
# 3. Logistic Regression is a Linear Model
# 4. Logistic Regression uses linear Model in the backend so named as Logistic Regression (Instead of
#        Classification)
#
# 5. In Logistic Regression we do use LogLOss Function as a Cost Function
#
# - In logistic regression our Targer variable will be a catagorical or discreate nature

# %% [raw]
# - That means Logistic regression is usually used for Binary classification problems.
#
# - Binary Classification refers to predicting the output variable that is discrete in two classes.
#
# - A few examples of Binary classification are Yes/No, Pass/Fail, Win/Lose, Cancerous/Non-cancerous, spam or Not-spam, 0 or 1 etc.

# %% [raw]
# 1. We are using linear Regression line in the Linear Regression Algorithm, Whereas we are using
# Sigmoid Function or Curve here in the Logistic Regression.
#
# Y = MX + C

# %% [markdown]
# ## Logit odd
# https://medium.com/wicds/logistic-regression-understanding-odds-and-log-odds-61aecdc88846

# %% [markdown]
# formula for logit odd:- ![image.png](attachment:image.png)
#
# p	=	probability
#
# p	=	probability
#  log(p/(1-p))	=	corresponding odds

# %% [raw]
# - Logistic Regression uses logit() to classify the outcomes
#
# - If the probability of an event occurring (P) and the probability that it will not occur is (1-P)
#     - Odds Ratio = P/(1-P)
#     - Taking the log of Odds ratio gives us:
#         - Log of Odds = log (p/(1-P))
#     - This is nothing but the logit function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Note: Probability ranges from 0 to 1, Odds range from 0 to ∞, Log Odds range from −∞ to ∞, That is why the log odds are used to avoid modeling a variable with a restricted range such as probability.

# %% [markdown]
# ## Logit() and Sigmoid()

# %% [raw]
# The logit function maps probabilities to the full range of real numbers required prior to modeling.
#
# The inverse of the logit function is the sigmoid function. That is, if you have a probability p, sigmoid(logit(p)) = p. The sigmoid function maps arbitrary real values back to the range [0, 1]. We can also say sigmoid function as the generalized form of logit function.

# %% [markdown]
# ### Read Artical for What if we impliment linear regression on logistic regression
#
# - Analytics vidya
# https://www.analyticsvidhya.com/blog/2021/07/an-introduction-to-logistic-regression/
#
#
# - Towords Data science
# https://towardsdatascience.com/introduction-to-logistic-regression-66248243c148

# %% [markdown]
# #### The reasons why we should not use Linear regression on classification problems
# - The two limitations of using a linear regression model for classification problems are:
#
#     - 1. the predicted value may exceed the range (0,1)
#     - 2. error rate increases if the data has outliers
#
# - That is why we need to use logistic regression in classification problems.

# %% [raw]
# The hypothesis of logistic regression tends it to limit the cost function between 0 and 1
# - That means the outplut of the logistic regression will always be in 0 and 1. and when we use linear regression on calssification problem value may exced the range (0,1), and sometimes it gives miscalssification values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## What is Sigmoid Function

# %% [raw]
# - In order to map predicted values to probabilities, we use the Sigmoid function. The function maps any real value into another value between 0 and 1. In machine learning, we use sigmoid to map predictions to probabilities.
# - It uses a loss function called log loss to calculate the Error.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Y = MX + C
# - e = Eular's Constant
# - e = 2.718
# ![image.png](attachment:image.png)

# %% [raw]
# P(Y) = 1/(1 + e^-(MX + C)

# %% [markdown]
# ### LogLoss Function

# %% [raw]
# - Log - loss is indicative of how close the prediction probability is to the corresponding actual/true value (0 or 1 in case of binary classification). The more the predicted probability diverges from the actual value, the higher is the log-loss value.
#
# - It uses a loss function called log loss to calculate the Error.
# - 1. if the value is less than 0.5, higher is the log-loss value
# - 2. if the value is grater than 0.5, lower is the log-loss value

# %% [markdown]
# ### Why can't we use cost function in logistic Regression ?

# %% [raw]
# - our prediction function is non-linear due to "sigmoid tranformation", squaring this prediction as we do in the MSE results in non-convex curve with many local minimums. if our cost function (MSE) has many local minimas, the gradient descent algorithm may not find the Optimum global minimum, therefore we use cross entropy log loss function.

# %% [markdown]
# - Logloss Functions
# https://towardsdatascience.com/intuition-behind-log-loss-score-4e0c9979680a#:~:text=Log%2Dloss%20is%20indicative%20of,is%20the%20log%2Dloss%20value.
#
# -
#
# - Logloss Functions
# https://medium.com/analytics-vidhya/understanding-the-loss-function-of-logistic-regression-ac1eec2838ce

# %% [markdown]
# #  How does Gradient Descent work in Logistic Regression?
# - https://www.analyticsvidhya.com/blog/2021/08/conceptual-understanding-of-logistic-regression-for-data-science-beginners/#:~:text=Gradient%20descent%20changes%20the%20value,loss%20function%20of%20our%20model

# %% [markdown]
# h0(X) = Pi
# ![image.png](attachment:image.png)

# %% [markdown]
# - log(Pi)
# ![image.png](attachment:image.png)
#
# - log(1-Pi)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The above two functions can be compressed into a single function i.e.
# - Equation for the LogLoss Function
#
# ![image.png](attachment:image.png)

# %% [raw]
# - 1. Log Loss Function measures the performance of the Classifiaction model, where the ouput is in Probability value between 0 and 1.
#
# - 2. The Goal of the machine learning model is to minimize the value, A perfect model would have a logloss = 0
#
# - 3. the value of logloss can be between 0 and infinity.
#
# - 4. logloss increases as the prediction probability diverges the actual lable.
#
# - 5. Higher the probability prediction value(Pi), lower the logloss function.(LL)
#
# - 6. Lower the probability prediction value (Pi), Higher the logloss function.(LL)
#
# - 7. we will get higher logloss value, when there is misclassified data points .
#
# - 8. we will get Lower logloss value, when there is corectly classified data points.

# %% [markdown]
# ![image.png](attachment:image.png)
# ###### NOTE:- logloss function penalizes confident and wrong predictions more than it rewards condident and right predictions
#
# ###### NOTE:- Logloss function penalizes missclassifications more as compaired to mean squared error

# %% [markdown]
# ## Confusion Matrix
# https://towardsdatascience.com/understanding-confusion-matrix-a9ad42dcfd62

# %% [markdown]
# https://medium.com/analytics-vidhya/confusion-matrix-accuracy-precision-recall-f1-score-ade299cf63cd

# %% [raw]
#  it is a performance measurement for machine learning classification problem where output can be two or more classes. It is a table with 4 different combinations of predicted and actual values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We describe predicted values as Positive and Negative and actual values as True and False.
# ![image.png](attachment:image.png)

# %% [raw]
# - It is extremely useful for measuring Recall, Precision, Specificity, Accuracy, and most importantly AUC-ROC curves.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. TPR (True Positive Rate)
# #### Sensitivity == Recall

# %% [raw]
# - TPR == Sensitivity == Recall
#
# - It states that the proportion of the +ve class are correctly classified by classifier
#     - TPR = Tp / (TP + FN)

# %% [markdown]
# ### 2. FNR (False Negative Rate) (Type 2 Error)

# %% [raw]
# - It states that the proportion of the +ve class are incorrectly classified by classifier
#     - FNR = FN / (TP + FN)

# %% [markdown]
# ###  3. TNR (True Negative Rate)

# %% [raw]
# - It states that the proportion of the -ve class are correctly classified by classifier
#     - TNR = TN / (TN + FP)

# %% [markdown]
# ### 4. FPR (False Positive Rate)  (Type 1 Error)
# #### (1 - Specificity)

# %% [raw]
# - FPR = (1 - Specificity)
# - It states that the proportion of the -ve class are incorrectly classified by classifier
#     - TNR = TN / (TN + FP)

# %% [markdown]
# # Classification Report
# https://medium.com/analytics-vidhya/confusion-matrix-accuracy-precision-recall-f1-score-ade299cf63cd

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Precision

# %% [raw]
# 1. Precision :-
#     - It states that all the classes that we have predicted Positive, How many are actually positive
#
#     - precision means what percentage of the positive predictions made were actually correct.
#
#
# - if precision  == 1 (Good Precision value)
# - precision = Tp / (TP + FP)
#
# - Precision should ideally be 1 (high) for a good classifier
#
# - If FP is low then the precision value will be high

# %% [markdown]
# #### Example

# %% [raw]
# Spam Filter :
#     Email is spam or not spam:
#         If mail is important and somehow it is going to the spam folder istead of coming it into the
#         inbox. through which user might miss the important data or information. For avoiding this      kind of practices we need to work on the false positive rate (FP). Through which we can reduce the chances of miss storage of email which we might recieve in the future.

# %% [raw]
# - In our example of heart disease, it’d look something like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# It could be translated into simple language as, of all patients classified as having heart disease, how many of them actually had heart disease?

# %% [markdown]
# ### 2. Recall

# %% [raw]
# - Recall :-
#     - From all the positive class or Out of total actual positive results, how many are predicted positve.
#
#     - Recall = TP / (TP + FN)
# - Recall should ideally be 1 (high) for a good classifier

# %% [markdown]
# ##### Example

# %% [raw]
# Positive or Negative:
#
#     if person is having cancer and model has predicted that, The person is not having cancer then there will be the High risk.
#     In this case we need to focus on the False Negative (FN). SO when we can reduce the FN then we are  able to get the right prediction from the model in terms of the Cancer.

# %%
TP = 25 ; FN = 5
25 / (25 + 5)
# Out:
# 0.8333333333333334

# %%
TP = 28 ; FN = 2
28 / (28 + 2)
# Out:
# 0.9333333333333333

# %% [markdown]
# ###### NOTE :- In classification report we alway try to reduce the Error that are in False Negative and False Positive class
#
# - precision is gretter when False Positive (FP) is Lower
# - Recall is gretter when False Negative (FN) is Lower

# %% [markdown]
# ### 3. F1-Score

# %% [raw]
# - When FN and FP both are importnat then we do consider F1-score.
#
#  - If the cost of false positives and false negatives are very different, it’s better to look at both Precision and Recall.
#
# - it is hard to compare two model with low precision and High Recall and vise versa. in that case we use F1-score in order to make them comparable. it help us to measure the precision and recall at the same time, it uses harmonic mean at the place of Arithmatic mean by panishing the value more.
#
# - F1 Score becomes 1 only when precision and recall are both 1. F1 score becomes high only when both precision and recall are high. F1 score is the harmonic mean of precision and recall and is a better measure than accuracy.
#
# - Standard Formula :-
#     Fβ-Score = (1 + β²) * precision * Recall / β² * precision + Recall
#
#
# when β = 1:
#     F1-score = 2 * precision * Recall / (Precision + Recall)
#
# When Beta = 1, Then we do focus on the FP and FN
# When Beta = 0.5, Then  we do focus on FP
# When Beta = 2 , Then we do focus on FN

# %% [markdown]
# ### Accuracy

# %% [raw]
# Accuracy = (TP + TN) / (Tp + FN + TN + FP)

# %% [markdown]
# # AUC-ROC curve
# https://www.analyticsvidhya.com/blog/2020/06/auc-roc-curve-machine-learning/

# %% [markdown]
# ### 1. ROC (Receiver Operator Characteristic)

# %% [raw]
# The Recevier Operator Characteristic (ROC) curve is evaluation matrix for binary classification Problem.
#
# It is a probability curve that plots the TPR against FPR at various threshold values and essentially separates the ‘signal’ from the ‘noise’. The Area Under the Curve (AUC) is the measure of the ability of a classifier to distinguish between classes and is used as a summary of the ROC curve.
#
# The higher the AUC, the better the performance of the model at distinguishing between the positive and negative classes.
#
# When AUC = 1, then the classifier is able to perfectly distinguish between all the Positive and the Negative class points correctly. If, however, the AUC had been 0, then the classifier would be predicting all Negatives as Positives, and all Positives as Negatives.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Example:-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Overfitting and Underfitting

# %% [markdown]
# ### 1. Underfitting
# ##### (High Bias, Low Variance)

# %% [raw]
# - Underfitting :-
#     When the given model neaither learns from training dataset nor from Test dataset (unseen dataset), i.e it will have high error rates in Training Dataset and Low error rates in test dataset, but still it will have how accuracy in traning model and test model.
#
#     - Low Training Accuracy
#     - Low Testing Accuracy
#
# - Example:-
#     -  Training Accuracy :- 65%
#     -  Testing Accuracy :- 60%

# %% [markdown]
# ### 2. Overfitting
# #### (Low Bias, High Variance)

# %% [raw]
# - Overfitting :-
#     When the given Model Performes well on Training dataset but struggle to performe well on testing dataset (Unseen data). i.e it will have low Errors in Training sets but high Errors rates in Test data sets. therefore it will have High Accuracy on trainig set and Low Accuracy on test sets
#
#     - High Training Accuracy
#     - Low Testing Accuracy
#
# - Example :-
#     - Training Accuracy :- 95%
#     - Testing Accuracy :- 80%

# %% [markdown]
# # Bias Variance Trade-off
# https://towardsdatascience.com/understanding-the-bias-variance-tradeoff-165e6942b229

# %% [markdown]
# ![image.png](attachment:image.png)
# - M1 = High Bias, Low Variance
# - M2 = Low Bias, Low Variance (Perfect Model)
# - M3 = Low Bias, High Variance

# %% [markdown]
# ### 1. Bias

# %% [raw]
# - Bias :-
#     Bias is nothing but The Training Errors. Model with high bias pays very little attention to the training data and oversimplifies the model. It always leads to high error on training and test data.

# %% [markdown]
# ### 2. Variance

# %% [raw]
# - Variance :-
#      Variance is nothing but the Testing Errors. Model with high variance pays a lot of attention to training data and does not generalize on the data which it hasn’t seen before. As a result, such models perform very well on training data but has high error rates on test data.
#
# - The Difference between the accuracies of different datasets (Training and Testing Datasets)

# %% [markdown]
# #####  NOTE : - Master Model or Best Model would have LOW BIAS and LOW VARIANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # How to avoid Underfitting and Overfitting

# %% [raw]
# 1. Underfitting :
#     it occures when the dimentionality of the dataset is less (less feature and rows)
#
#     Low Training Accuracy
#     Low Testing Accuracy
#
# 1. Add more Parameters (more features) (20 >> 25 or 30)
# 2. Use Correlated Features
# 3. Remove Outliers
# 4. Replace the missing values by mean, Median and Mode
# 5. Increase the Data Size (20000 >> 25000)

# %% [raw]
# 2. Overfitting :
#     it occures when the dimentionality of the dataset is large (number of feature and rows) and in nonlinear ML models.
#
#
#     High training Accuracy
#     Low Testing Accuracy
#
#
# 1. Use less Parameters (less features)
# 2. Use Hyperparameter Tuning
# 3. We can Regularization Techniques (L1 and L2 Regularization)
# 4. Remove Outliers
# 5. We can go ahead with the Cross Validation Technique
# 6. Increase the data size (10000 >> 20000)

# %% [markdown]
# ### Multiclassification problem
# https://towardsdatascience.com/multiclass-classification-evaluation-with-roc-curves-and-roc-auc-294fd4617e3a

# %% [raw]
# - In Multiclassification problems there will be two or more unique values
# - it follows OVR technique
#     - classifier = LogisticRegression(multi_class = "ovr")

# %% [markdown]
# #### OVR (One vs Rest)

# %% [markdown]
# - ovr is technique to classify the multiclssification values
#     - ex. 0,1,2,3, red, green, yellow, low, medium, high
# - The number of Unique values in Target feature equal to number of Confusion matrixs
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Multicalssification confusion matrix
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Evaluation metrics in Logistic regression
# - 1. classification_report
# - 2. f1_score
# - 2. roc_auc_score
# - 3. fpr,tpr,threshold = roc_curve()
# - 4. confusion_matrix
# - 5. multilabel_confusion_matrix

# %%
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix, multilabel_confusion_matrix, f1_score
