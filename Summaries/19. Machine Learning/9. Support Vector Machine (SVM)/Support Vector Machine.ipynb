# %% [markdown]
# ## Support Vector Mchine
# 1. https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
#
# 2. https://towardsdatascience.com/support-vector-machines-svm-c9ef22815589
#
# 3. https://towardsdatascience.com/support-vector-machine-svm-719e530a725f

# %% [markdown]
# ## linearly separable data

# %% [raw]
# It is a supervised machine learning algorithm which is use for classification as well as regression problem but mostely it is use for classification  objectives.
#
# the aim of the support vector mahchine algorithm is to find the hyperplane in N-Dimentional space  (N — the number of features), which distictly classfies the data points

# %% [raw]
# 1. Hyperplanes :- Hyperplanes decision boundaries that helps us to classify the datapoints. Data                       points falling on either side of the hyperplane can be attributed to different                       classes. Also, the dimension of the hyperplane depends upon the number of                           features. If the number of input features is 2, then the hyperplane is just a                       line. If the number of input features is 3, then the hyperplane becomes a two-                       dimensional plane. It becomes difficult to imagine when the number of features                       exceeds 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Support Vectors :- Support vectors are data points that are closer to the hyperplane and influence                      the position and orientation of the hyperplane. Using these support vectors, we                      maximize the margin of the classifier. Deleting the support vectors will change                      the position of the hyperplane. These are the points that help us build our SVM.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Margines :- Margins are the Distances between two support vectors, larger the margin higher the                 possibilitis to classify the datapoints by the SVM algorithm, if the margine is small               then the classifying the datapoints would be difficult and will lead to                             missclassification of the datapoints.

# %% [raw]
# Hard Marginal plane :-
# 	if the datapoints are correctly classified on both the sides (+ve and -ve sides) if this phenominan is occured then this is known as Hard marginal plane. because there will be no Errors
#
#
# Soft Marginal Plane :-
#     if the datapoints from the blue class get missclassifed in +ve or green side margin or vise 	     versa this phenonmena is known as called soft margin. Because there will be erros

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Non Linearly separable data
# https://towardsdatascience.com/support-vector-machine-simply-explained-fee28eba5496#:~:text=To%20sum%20up%2C%20SVM%20in%20the%20linear%20nonseparable%20cases%3A,for%20linear%20non%2Dseparable%20cases.

# %% [raw]
# - if the Data is Non-Linearly separable data, in that case we increase the features by adding         some extra features and tranforming the vectors to higher dimensions to sepearate the classes.       after converting it into Higher Dimension then the data will be linearly separable.
#
# - We have some functions which can help to transform the data to higher dimensions. These             functions are known as kernels.

# %% [markdown]
# ## Kernals :-

# %% [raw]
# - Linear
# - Polynomial
# - sigmoid
# - Radial Basis Function (RBF)
# - precompute (We don't use this kernel)

# %% [markdown]
# ## Advantages and Disadvantages

# %% [raw]
# Advantages :
#     1.  Memory efficient
# 	2. Linear SVM is more effective than other algorithm if the number of features are highe (>1000)

# %% [raw]
# Disadvantages:
#
#    1. Feature scaling
#    2. Tends to get slower as number of examples increases
#    3. Hard margin leads to overfitting

# %% [markdown]
# #### hyperparameters for SVM

# %% [raw]
# 1. kernals
# 2. C :- Number of permitted errors. Large C gives a narrow margin and vice versa.

# %% [raw]
# C :- if C is higher then smaller the margin, and if C is smaller the Higher the Margin.
