# %% [markdown]
# # Normality

# %%
Range >> 30 t0 40

Age = [30,40,35,36,34,33,38]

# %%
import pandas as pd
import numpy as np

# %%
Age = [30,40,35,36,34,33,38]
std = np.std(Age)

print('Standard Deviation is :',std)
print()
mean = np.mean(Age)
print('Mean of Age is :',mean)
# Out:
# Standard Deviation is : 3.0438965360946453
#
# Mean of Age is : 35.142857142857146

# %%
1 * 3.04  = 3.04

-1 * 3.04 = -3.04
# Out:
# 3.04

# %%
35.14 + 3.04
# Out:
# 38.18

# %%
35.14 - 3.04
# Out:
# 32.1

# %%
age = [30,40,35,36,34,33,38]

df = pd.DataFrame({'Age':age})
# df

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.histplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'], kde = True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
Value = [30,40,50,55,35,60,80,90,150]
df = pd.DataFrame({'age':Value})
sns.histplot(df['age'], kde = True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.distplot(df['age'], kde = True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [raw]
# Mean Absolute Error :
#
#     MAE = Sum(|Ya - Yp|)/N

# %% [markdown]
# # RMSE

# %% [raw]
# Root Means Squared Error :
#
#     RMSE = np.sqrt(MSE)

# %% [raw]
# R2Score = Coefficient of Determination
#
# R2Score = 1 - SSE/SST
#
#         = (SST - SSE)/SST
#
#
# R2Score >> +1  >> Best value >> SSE = 0
#
# R2Score >> 0   >> Worst Value >> SSE == SST
#
# R2Score >> -Ve >> SST < SSE
#
#
# 0 is the worst Score in terms of the Coefficient of Determination
# 1 is the best Score in terms of the Coefficient of Determination

# %% [markdown]
# # Adjusted R2 Score

# %% [raw]
# Adjusted R2 Score = R2 - (K - 1) (1 - R2)/(n - K)
#
# n = Total number of samples or sample size
# k = Number of input or independent variables
