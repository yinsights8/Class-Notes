# %%
import pandas as pd
import sqlalchemy as sa

# %%
client = sa.create_engine("mysql+pymysql://root:Y45hDhakade123@localhost:3306/stud_data")
client
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/stud_data)

# %% [markdown]
# ### 1. read_sql_table()

# %%
data = pd.read_sql_table("emp_data",client)
data.head()
# Out:
#     EmpID     FName     LName Gender                         EMail  Salary  \
# 0  677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1  940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2  428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3  408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4  193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
#
#         LOC  MGR_ID  DEPT_ID
# 0    DALLAS  677509       10
# 1   CHICAGO  940761       10
# 2   CHICAGO  428945       10
# 3  NEW YORK  408351       20
# 4    DALLAS  193819       20

# %% [markdown]
# ## 2. read_sql_query

# %%
data = pd.read_sql_query("select * from emp", client)
data.head()
# Out:
#    emp_ID emp_NAME DEPT_NAME  SALARY
# 0     101    Mohan     Admin    4000
# 1     102    rahul        HR    3000
# 2     103    Akbar        IT    4000
# 3     104   Dorvin   Finance    6500
# 4     105    Rohit        HR    3000

# %%
data = pd.read_sql_query("select * from emp_data", client)
data.head()
# Out:
#     EmpID     FName     LName Gender                         EMail  Salary  \
# 0  677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1  940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2  428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3  408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4  193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
#
#         LOC  MGR_ID  DEPT_ID
# 0    DALLAS  677509       10
# 1   CHICAGO  940761       10
# 2   CHICAGO  428945       10
# 3  NEW YORK  408351       20
# 4    DALLAS  193819       20

# %% [markdown]
# ### read_sql

# %%
data = pd.read_sql("select * from placement", client)
data.head()
# Out:
#    roll_no  Age Gender                  branch  Internships  CGPA  Hostel  \
# 0        1   22   Male                   Civil            0     6       1
# 1        2   22   Male  Information Technology            0     7       0
# 2        3   21   Male        Computer Science            0     6       0
# 3        4   22   Male              Electrical            2     6       0
# 4        5   22   Male        Computer Science            1     6       0
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  0            0
# 1                  0            0
# 2                  1            0
# 3                  1            0
# 4                  0            0

# %%
data = pd.read_sql("placement", client)
data.head()
# Out:
#    roll_no  Age Gender                  branch  Internships  CGPA  Hostel  \
# 0        1   22   Male                   Civil            0     6       1
# 1        2   22   Male  Information Technology            0     7       0
# 2        3   21   Male        Computer Science            0     6       0
# 3        4   22   Male              Electrical            2     6       0
# 4        5   22   Male        Computer Science            1     6       0
#
#    HistoryOfBacklogs  PlacedOrNot
# 0                  0            0
# 1                  0            0
# 2                  1            0
# 3                  1            0
# 4                  0            0

# %%
data = pd.read_sql("""
select * from (
select *,
rank() over (partition by dept_name order by salary desc) as rnk,
dense_rank() over (partition by dept_name order by salary desc) dense_rnk 
from emp) sq
where dense_rnk<4
""", client)

data.head()
# Out:
#    emp_ID emp_NAME DEPT_NAME  SALARY  rnk  dense_rnk
# 0     120   Monica     Admin    5000    1          1
# 1     101    Mohan     Admin    4000    2          2
# 2     108   Maryam     Admin    4000    2          2
# 3     113  Gautham     Admin    2000    4          3
# 4     104   Dorvin   Finance    6500    1          1

# %%
data.to_sql("emp_rank",con=client, index=False, if_exists="replace")
# Out:
# 16
