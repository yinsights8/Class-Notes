# %% [markdown]
# # Reading and Writing DataFrames
# - pd.read_csv()
# - pd.read_excel()
# - df.to_csv()
# - df.to_excel()
# - df.to_dict()
# - df.to_json()

# %% [markdown]
# # 1. read_csv()
# - 1. index_col
# - 2. header
# - 3. usecol
# - 4. delimiter

# %%
import pandas as pd
import numpy as np

# %%
MoviesDf = pd.read_csv("movies_data.csv")
MoviesDf.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
MoviesDf = pd.read_csv("movies_data.csv",index_col="title")
MoviesDf.head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
MoviesDf = pd.read_csv("movies_data.csv",header=None)
MoviesDf.head()
# Out:
#              0                         1               2       3         4  \
# 0  star_rating                     title  content_rating   genre  duration
# 1          9.3  The Shawshank Redemption               R   Crime       142
# 2          9.2             The Godfather               R   Crime       175
# 3          9.1    The Godfather: Part II               R   Crime       200
# 4            9           The Dark Knight           PG-13  Action       152
#
#                                                    5
# 0                                        actors_list
# 1  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
MoviesDf = pd.read_csv("movies_data.csv",usecols=["title","genre","actors_list"])
MoviesDf.head()
# Out:
#                       title   genre  \
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.read_csv("demo.csv")
# Out:
#     name  age location
# 0  ankur   26     Pune

# %%
pd.read_csv("demo.csv")
# Out:
#   name-age-location
# 0     ankur-26-Pune

# %%
pd.read_csv("demo.csv",delimiter="-")
# Out:
#     name  age location
# 0  ankur   26     Pune

# %%
pd.read_csv("demo.csv")
# Out:
#   name%age%location
# 0     ankur%26%Pune

# %%
pd.read_csv("demo.csv",delimiter="%")
# Out:
#     name  age location
# 0  ankur   26     Pune

# %% [markdown]
# # 2. Read Excel File
# - 1. index_col
# - 2. usecols

# %%
df = pd.read_excel("Emp_Records.xlsx")
df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
df = pd.read_excel("Emp_Records.xlsx",index_col="Emp ID")
df.head()
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36             60           13.68  168251
# 940761     Brenda       47.02             60            9.01   51063
# 428945        Joe       54.15             68            0.98   50155
# 408351      Diane       39.67             51           18.30  180294
# 193819   Benjamin       40.31             58            4.01  117642
#
#                 City
# Emp ID
# 677509        Denver
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# 193819       Fremont

# %%
df = pd.read_excel("Emp_Records.xlsx",sheet_name="emp_salary")
df.head()
# Out:
#    Salary          City
# 0  168251        Denver
# 1   51063     Stonewall
# 2   50155  Michigantown
# 3  180294      Hydetown
# 4  117642       Fremont

# %% [markdown]
# # 3. Create CSV File

# %%
df = pd.DataFrame(
    {
        "Name" : ["Shrikar","Gaurav"],
        "salary" : [1600000,1700000]
    }
)
df
# Out:
#       Name   salary
# 0  Shrikar  1600000
# 1   Gaurav  1700000

# %%
df.to_csv("Demo1.csv")

# %%
df.to_csv("Demo2.csv",index=False)

# %%
MoviesDf
# Out:
#                                                title      genre  \
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# ...

# %%
actiondf = MoviesDf.loc[MoviesDf["genre"] == "Action"]
actiondf
# Out:
#                                                title   genre  \
# 3                                    The Dark Knight  Action
# 11                                         Inception  Action
# 12    Star Wars: Episode V - The Empire Strikes Back  Action
# 19                                         Star Wars  Action
# 20                                        The Matrix  Action
# ..                                               ...     ...
# 918                                   Running Scared  Action
# 954                                            X-Men  Action
# 963                                  La Femme Nikita  Action
# 967                                         The Rock  Action
# 976  Master and Commander: The Far Side of the World  Action
#
#                                            actors_list
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 11   [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 12   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# ...

# %%
actiondf.to_csv("Action_Cat.csv",index=False)

# %% [markdown]
# # 4. Creating Excel File

# %%
MoviesDf.head()
# Out:
#                       title   genre  \
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
MoviesDf.to_excel("ExcelMovie.xlsx",index=False)

# %%
MoviesDf.to_excel("Movies2.xlsx",index=False,sheet_name="Action Movie Details")

# %%
writer = pd.ExcelWriter("movies3.xlsx")

# %%
drama = MoviesDf.loc[MoviesDf["genre"] == "Drama"]
drama
# Out:
#                                title  genre  \
# 5                       12 Angry Men  Drama
# 9                         Fight Club  Drama
# 13                      Forrest Gump  Drama
# 16   One Flew Over the Cuckoo's Nest  Drama
# 17                     Seven Samurai  Drama
# ..                               ...    ...
# 958               My Sister's Keeper  Drama
# 968              The English Patient  Drama
# 970                      Wonder Boys  Drama
# 972                   Blue Valentine  Drama
# 973            The Cider House Rules  Drama
#
#                                            actors_list
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 9    [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 13     [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# 16   [u'Jack Nicholson', u'Louise Fletcher', u'Mich...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# ..                                                 ...
# ...

# %%
drama.to_excel(writer, "Mov.xlsx",index=False)
writer.save()

# %% [markdown]
# # Create Dictionary

# %%
df = pd.DataFrame()

# %%
df["Num"] = [1,2,3,4,5]
df
# Out:
#    Num
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
df["Square"]  = df["Num"] ** 2
df["Cube"]  = df["Num"] ** 3

# %%
df
# Out:
#    Num  Square  Cube
# 0    1       1     1
# 1    2       4     8
# 2    3       9    27
# 3    4      16    64
# 4    5      25   125

# %%
df.to_dict(orient="record")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11788\1432459374.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   df.to_dict(orient="record")
# [{'Num': 1, 'Square': 1, 'Cube': 1},
#  {'Num': 2, 'Square': 4, 'Cube': 8},
#  {'Num': 3, 'Square': 9, 'Cube': 27},
#  {'Num': 4, 'Square': 16, 'Cube': 64},
#  {'Num': 5, 'Square': 25, 'Cube': 125}]

# %% [markdown]
# # Create JSON File

# %%
df
# Out:
#    Num  Square  Cube
# 0    1       1     1
# 1    2       4     8
# 2    3       9    27
# 3    4      16    64
# 4    5      25   125

# %%
df.to_json("Numbers.json")
# Out:
#    Num  Square  Cube
# 0    1       1     1
# 1    2       4     8
# 2    3       9    27
# 3    4      16    64
# 4    5      25   125

# %%
pd.read_json("Numbers.json")
# Out:
#    Num  Square  Cube
# 0    1       1     1
# 1    2       4     8
# 2    3       9    27
# 3    4      16    64
# 4    5      25   125
