# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading and Writing Dataframe
# - df.read_csv()
# - df.read_excel()
# - df.read_json()
# - df.to_csv()
# - df.to_excel()
# - df.to_json()

# %%
# 1. pd.read_csv()
# -

# %%
df = pd.read_csv("movies_data.csv")
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df_ind = pd.read_csv("movies_data.csv",index_col=["title", "star_rating","duration"])
df_ind
# Out:
#                                                                      content_rating  \
# title                                           star_rating duration
# The Shawshank Redemption                        9.3         142                   R
# The Godfather                                   9.2         175                   R
# The Godfather: Part II                          9.1         200                   R
# The Dark Knight                                 9.0         152               PG-13
# Pulp Fiction                                    8.9         154                   R
# ...                                                                             ...
# Tootsie                                         7.4         116                  PG
# Back to the Future Part III                     7.4         118                  PG
# Master and Commander: The Far Side of the World 7.4         138               PG-13
# ...

# %%
headr_df = pd.read_csv("movies_data.csv",header=None)
headr_df.head()
# Out:
#              0                         1               2       3         4  \
# 0  star_rating                     title  content_rating   genre  duration
# 1          9.3  The Shawshank Redemption               R   Crime       142
# 2          9.2             The Godfather               R   Crime       175
# 3          9.1    The Godfather: Part II               R   Crime       200
# 4            9           The Dark Knight           PG-13  Action       152
#
#                                                    5
# 0                                        actors_list
# 1  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
usecol = pd.read_csv("movies_data.csv",usecols=['star_rating', "content_rating","genre","duration"])
usecol.head()
# Out:
#    star_rating content_rating   genre  duration
# 0          9.3              R   Crime       142
# 1          9.2              R   Crime       175
# 2          9.1              R   Crime       200
# 3          9.0          PG-13  Action       152
# 4          8.9              R   Crime       154

# %%
dataf = pd.DataFrame({
    "Name" : ["sun", "earth", "jupyter"],
    "years": [100000,200000,300000]
})

# %%
dfg = pd.read_csv("demo.csv")
dfg
# Out:
#   name%age%company%EmpId
# 0     Aakash%"Tcs"%"123"

# %%
dfg = pd.read_csv("demo.csv",delimiter="%")
dfg
# Out:
#      name  age  company  EmpId
# 0  Aakash  Tcs      123    NaN

# %%
read_only = pd.read_csv("movies_data.csv", usecols=["actors_list"])
read_only.head()
# Out:
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
for i in read_only["actors_list"].head():
    for j in i:
# Out:
#   Input In [11]
#     for j in i:
#                ^
# IndentationError: expected an indented block

# %%
[u'Marlon Brando', u'Al Pacino', u'James Caan'].removeprefix(" ")

# %%
read = pd.read_csv("Deo.csv")
read

# %%
read = pd.read_csv("Deo.csv",delimiter=">")

# %%
read_csv = pd.read_csv("Company.csv")
read_csv
# Out:
#      name joiningdate companyname location
# 0  Ankush  12-10-2022         TSC     Pune
# 1   Madan  15-12-2010      Oracle   Mumbai

# %% [markdown]
# ## Create Csv File

# %%
data = pd.DataFrame({
    "Name" : ["Sun", "Earth", "Mars", "Jupyter"],
    "Ages" : [200000, 300000, 400000, 500000]
})

# %%
data.to_csv("Planet_names",index=True)

# %%
data.to_csv("Planet_names",index=False)

# %%
df[df["genre"] == "Action"]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df["genre"].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
addMov = df[df["genre"] == "Western"].sort_values("star_rating").reset_index(drop=True)
addMov.to_csv("Western_Movies.csv")
