# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame()
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.insert(0, "Col1", [1,2,3,4,5])
data
# Out:
#    Col1
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
data
# Out:
#    Col1
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
data.insert(0, "Col1", [1,2,3,4,5],allow_duplicates=True)
data
# Out:
#    Col1  Col1
# 0     1     1
# 1     2     2
# 2     3     3
# 3     4     4
# 4     5     5

# %%
data["Col2"] = [11,12,13,14,15]

# %%
data
# Out:
#    Col1  Col1  Col2
# 0     1     1    11
# 1     2     2    12
# 2     3     3    13
# 3     4     4    14
# 4     5     5    15

# %%
data.rename(columns={"Col1": "C1"}, inplace=True)

# %%
data.rename(index={0: "1st", 1 : "2nd"},inplace= True)

# %%
data
# Out:
#      C1  C1  Col2
# 1st   1   1    11
# 2nd   2   2    12
# 2     3   3    13
# 3     4   4    14
# 4     5   5    15

# %%
data.columns = list("ABC")

# %%
data.index = list("pqrst")

# %%
data
# Out:
#    A  B   C
# p  1  1  11
# q  2  2  12
# r  3  3  13
# s  4  4  14
# t  5  5  15

# %%
dataset = pd.read_csv("movies_data.csv")

# %%
dataset.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
dataset["genre"].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
dataset["genre"].value_countsunts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
dataset.groupby("genre").first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
dataset.groupby("genre").nth(0)
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
dataset.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
dataset["content_rating"].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
dataset["content_rating"].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
dataset.groupby(["content_rating"]).get_group("R")
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 968          7.4       The English Patient              R      Drama
# 969          7.4       Law Abiding Citizen              R      Crime
# 970          7.4               Wonder Boys              R      Drama
# 971          7.4        Death at a Funeral              R     Comedy
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
dataset.groupby("content_rating").get_group("GP")
# Out:
#      star_rating             title content_rating      genre  duration  \
# 282          8.1  Harold and Maude             GP     Comedy        91
# 302          8.0            Patton             GP  Biography       172
# 691          7.7    Kelly's Heroes             GP     Action       144
#
#                                            actors_list
# 282   [u'Ruth Gordon', u'Bud Cort', u'Vivian Pickles']
# 302  [u'George C. Scott', u'Karl Malden', u'Stephen...
# 691  [u'Clint Eastwood', u'Telly Savalas', u'Don Ri...

# %%
dataset.groupby(["content_rating", "genre", "star_rating"]).get_group(("PG-13", "Action", 8)).reset_index(drop=True)
# Out:
#    star_rating             title content_rating   genre  duration  \
# 0          8.0         Furious 7          PG-13  Action       137
# 1          8.0         Star Trek          PG-13  Action       127
# 2          8.0          Serenity          PG-13  Action       119
# 3          8.0     Casino Royale          PG-13  Action       144
# 4          8.0         Spartacus          PG-13  Action       197
# 5          8.0  Edge of Tomorrow          PG-13  Action       113
#
#                                          actors_list
# 0  [u'Vin Diesel', u'Paul Walker', u'Dwayne Johns...
# 1  [u'Chris Pine', u'Zachary Quinto', u'Simon Pegg']
# 2  [u'Nathan Fillion', u'Gina Torres', u'Chiwetel...
# 3     [u'Daniel Craig', u'Eva Green', u'Judi Dench']
# 4  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 5    [u'Tom Cruise', u'Emily Blunt', u'Bill Paxton']

# %%
dataset.groupby(["content_rating"]).get_group(("PASSED")).reset_index(drop=True).sort_values("star_rating")
# Out:
#    star_rating                        title content_rating      genre  \
# 6          7.7             Forbidden Planet         PASSED     Action
# 5          8.0            The Lady Vanishes         PASSED     Comedy
# 3          8.1             The Wizard of Oz         PASSED  Adventure
# 4          8.1                    Duck Soup         PASSED     Comedy
# 2          8.2  The Best Years of Our Lives         PASSED      Drama
# 1          8.4             Double Indemnity         PASSED      Crime
# 0          8.6                  City Lights         PASSED     Comedy
#
#    duration                                        actors_list
# 6        98  [u'Walter Pidgeon', u'Anne Francis', u'Leslie ...
# 5        96  [u'Margaret Lockwood', u'Michael Redgrave', u'...
# 3       102  [u'Judy Garland', u'Frank Morgan', u'Ray Bolger']
# 4        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 2       172  [u'Fredric March', u'Dana Andrews', u'Myrna Loy']
# ...

# %%
c_data = dataset.copy()

# %%
c_data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
c_data["genre"].value_countsunts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
c_data.loc[c_data["genre"] == "Sci-Fi"].sort_values("star_rating")
# Out:
#      star_rating                          title content_rating   genre  \
# 637          7.7           The Butterfly Effect              R  Sci-Fi
# 484          7.8  The Day the Earth Stood Still       APPROVED  Sci-Fi
# 408          7.9                        Gravity          PG-13  Sci-Fi
# 321          8.0                         Brazil              R  Sci-Fi
# 145          8.2                   Blade Runner              R  Sci-Fi
#
#      duration                                        actors_list
# 637       113  [u'Ashton Kutcher', u'Amy Smart', u'Melora Wal...
# 484        92  [u'Michael Rennie', u'Patricia Neal', u'Hugh M...
# 408        91  [u'Sandra Bullock', u'George Clooney', u'Ed Ha...
# 321       132  [u'Jonathan Pryce', u'Kim Greist', u'Robert De...
# 145       117  [u'Harrison Ford', u'Rutger Hauer', u'Sean You...

# %%
c_data[(c_data["genre"] == "Sci-Fi") & (c_data["content_rating"] == "R")]
# Out:
#      star_rating                 title content_rating   genre  duration  \
# 145          8.2          Blade Runner              R  Sci-Fi       117
# 321          8.0                Brazil              R  Sci-Fi       132
# 637          7.7  The Butterfly Effect              R  Sci-Fi       113
#
#                                            actors_list
# 145  [u'Harrison Ford', u'Rutger Hauer', u'Sean You...
# 321  [u'Jonathan Pryce', u'Kim Greist', u'Robert De...
# 637  [u'Ashton Kutcher', u'Amy Smart', u'Melora Wal...

# %%
for i in c_data["title"].head().index:
    c_data.iloc[i] = c_data.iloc[i].apply(lambda x : x.lower().endswith("r"))
c_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
#       1 for i in c_data["title"].head().index:
# ----> 2     c_data.iloc[i] = c_data.iloc[i].apply(lambda x : x.lower().endswith("r"))
#       3 c_data
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
# ...

# %%
c_data[["title"]]
# Out:
#                                                title
# 0                           The Shawshank Redemption
# 1                                      The Godfather
# 2                             The Godfather: Part II
# 3                                    The Dark Knight
# 4                                       Pulp Fiction
# ..                                               ...
# 974                                          Tootsie
# 975                      Back to the Future Part III
# 976  Master and Commander: The Far Side of the World
# 977                                      Poltergeist
# 978                                      Wall Street
#
# [979 rows x 1 columns]

# %%
c_data["title"].head().index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
c_data[["title"]].head(10)
# Out:
#                                            title
# 0                       The Shawshank Redemption
# 1                                  The Godfather
# 2                         The Godfather: Part II
# 3                                The Dark Knight
# 4                                   Pulp Fiction
# 5                                   12 Angry Men
# 6                 The Good, the Bad and the Ugly
# 7  The Lord of the Rings: The Return of the King
# 8                               Schindler's List
# 9                                     Fight Club

# %%
d = pd.DataFrame(c_data["title"].apply(lambda x : x.lower().startswith("t")))
d.head(10)
# Out:
#    title
# 0   True
# 1   True
# 2   True
# 3   True
# 4  False
# 5  False
# 6   True
# 7   True
# 8  False
# 9  False
