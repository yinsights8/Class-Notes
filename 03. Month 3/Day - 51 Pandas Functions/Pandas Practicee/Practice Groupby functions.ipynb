# %% [markdown]
# ## Groupby Functions
# - df.groupby
# - df.groupby.first()
# - df.groupby.get_group()

# %%
import pandas as pd
import numpy as np

# %%
m_dataset = pd.read_csv("movies_data.csv")

# %%
m_dataset.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
m_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
m_dataset.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
m_dataset[m_dataset["content_rating"].isna()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
m_dataset["genre"].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
m_dataset["genre"].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
m_dataset["genre"].nunique()
# Out:
# 16

# %%
len(m_dataset["genre"].unique())
# Out:
# 16

# %%
m_dataset.groupby("genre").nth(0)
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
m_dataset.groupby("genre").first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
m_dataset.groupby("genre").get_group("Action")
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
m_dataset.loc[m_dataset["genre"] == "Action"]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
m_dataset[m_dataset["genre"] == "Action"]
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
m_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
m_dataset["content_rating"].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
m_dataset["content_rating"].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
m_dataset["content_rating"].nunique()
# Out:
# 12

# %%
m_dataset.groupby("content_rating").get_group('PG-13').reset_index(drop=True)
# Out:
#      star_rating                                              title  \
# 0            9.0                                    The Dark Knight
# 1            8.9      The Lord of the Rings: The Return of the King
# 2            8.8  The Lord of the Rings: The Fellowship of the Ring
# 3            8.8                                          Inception
# 4            8.8                                       Forrest Gump
# ..           ...                                                ...
# 184          7.4                                            Lincoln
# 185          7.4                                          Limitless
# 186          7.4                                 The Simpsons Movie
# 187          7.4                              The Cider House Rules
# 188          7.4    Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 0            PG-13     Action       152
# 1            PG-13  Adventure       201
# ...

# %%
m_dataset.groupby("content_rating").get_group('TV-MA').reset_index(drop=True)
# Out:
#    star_rating                            title content_rating  genre  \
# 0          8.1  Who's Afraid of Virginia Woolf?          TV-MA  Drama
#
#    duration                                        actors_list
# 0       131  [u'Elizabeth Taylor', u'Richard Burton', u'Geo...

# %%
m_dataset.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
m_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
m_dataset["star_rating"].value_counts()
# Out:
# 7.6    124
# 7.8    116
# 7.7    113
# 7.5    108
# 8.1    103
# 8.0     97
# 7.9     75
# 8.2     51
# 7.4     49
# 8.3     43
# 8.4     37
# 8.5     23
# 8.6     15
# 8.7     10
# 8.9      6
# 8.8      5
# 9.2      1
# 9.0      1
# 9.1      1
# 9.3      1
# Name: star_rating, dtype: int64

# %%
m_dataset["star_rating"].unique()
# Out:
# array([9.3, 9.2, 9.1, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1,
#        8. , 7.9, 7.8, 7.7, 7.6, 7.5, 7.4])

# %%
m_dataset["star_rating"].nunique()
# Out:
# 20

# %%
m_dataset.groupby("star_rating").first()
# Out:
#                                                          title content_rating  \
# star_rating
# 7.4                                            Man on the Moon              R
# 7.5                                 Good Night, and Good Luck.             PG
# 7.6                                                  127 Hours              R
# 7.7                                        Remember the Titans             PG
# 7.8                                                  Tombstone              R
# 7.9           Birdman: Or (The Unexpected Virtue of Ignorance)              R
# 8.0                                                       Rope             PG
# 8.1                               Kingsman: The Secret Service              R
# 8.2                                    The Wolf of Wall Street              R
# 8.3                           The Treasure of the Sierra Madre      NOT RATED
# 8.4                                                          M      NOT RATED
# ...

# %%
m_dataset.groupby("star_rating").nth(0)
# Out:
#                                                          title content_rating  \
# star_rating
# 7.4                                            Man on the Moon              R
# 7.5                                 Good Night, and Good Luck.             PG
# 7.6                                                  127 Hours              R
# 7.7                                        Remember the Titans             PG
# 7.8                                                  Tombstone              R
# 7.9           Birdman: Or (The Unexpected Virtue of Ignorance)              R
# 8.0                                                       Rope             PG
# 8.1                               Kingsman: The Secret Service              R
# 8.2                                    The Wolf of Wall Street              R
# 8.3                           The Treasure of the Sierra Madre      NOT RATED
# 8.4                                                          M      NOT RATED
# ...

# %%
m_dataset.groupby("star_rating").get_group(7.4)
# Out:
#      star_rating                                            title  \
# 930          7.4                                  Man on the Moon
# 931          7.4                                     Mean Streets
# 932          7.4        Harry Potter and the Order of the Phoenix
# 933          7.4                                      Beetlejuice
# 934          7.4                             Crazy, Stupid, Love.
# 935          7.4                                        Excalibur
# 936          7.4                                        True Grit
# 937          7.4                                        Labyrinth
# 938          7.4                              Alice in Wonderland
# 939          7.4                                   Predestination
# 940          7.4                           Much Ado About Nothing
# 941          7.4                                 A Bridge Too Far
# 942          7.4                                  Raising Arizona
# ...

# %%
m_dataset.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
m_dataset[m_dataset["star_rating"] == 8.5]
# Out:
#     star_rating                                              title  \
# 40          8.5                                     The Green Mile
# 41          8.5                                       Sunset Blvd.
# 42          8.5                                        The Pianist
# 43          8.5                              The Dark Knight Rises
# 44          8.5                                          Gladiator
# 45          8.5                         Terminator 2: Judgment Day
# 46          8.5                                            Memento
# 47          8.5                                   Taare Zameen Par
# 48          8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 49          8.5                                       The Departed
# 50          8.5                                    Cinema Paradiso
# 51          8.5                                     Apocalypse Now
# 52          8.5                                 The Great Dictator
# ...

# %%
m_dataset[m_dataset["star_rating"] >= 9]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
m_dataset[(m_dataset["star_rating"] >= 8.5) & (m_dataset["genre"] == "Action")]
# Out:
#     star_rating                                           title  \
# 3           9.0                                 The Dark Knight
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 19          8.7                                       Star Wars
# 20          8.7                                      The Matrix
# 36          8.6                             Saving Private Ryan
# 37          8.6                         Raiders of the Lost Ark
# 43          8.5                           The Dark Knight Rises
# 44          8.5                                       Gladiator
# 45          8.5                      Terminator 2: Judgment Day
#
#    content_rating   genre  duration  \
# 3           PG-13  Action       152
# 11          PG-13  Action       148
# 12             PG  Action       124
# 19             PG  Action       121
# 20              R  Action       136
# 36              R  Action       169
# ...

# %%
m_dataset.groupby(["genre", "content_rating"]).get_group(("Action", "PG-13"))
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 43           8.5                            The Dark Knight Rises
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# 177          8.2                                     The Avengers
# 196          8.1                          Guardians of the Galaxy
# 240          8.1                             The Bourne Ultimatum
# 248          8.1                       X-Men: Days of Future Past
# 301          8.0                                        Furious 7
# 312          8.0                                        Star Trek
# 366          8.0                                         Serenity
# 380          8.0                                    Casino Royale
# ...

# %%
m_dataset.groupby(["content_rating","genre"]).get_group(("PG", "Action"))
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 37           8.6                         Raiders of the Lost Ark
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 327          8.0                    The Adventures of Robin Hood
# 420          7.9                       The Man Who Would Be King
# 586          7.7                 Star Trek II: The Wrath of Khan
# 748          7.6                        The Hunt for Red October
# 753          7.6                            Escape from Alcatraz
# 764          7.6            Indiana Jones and the Temple of Doom
# 908          7.5                                         Bullitt
#
#     content_rating   genre  duration  \
# 12              PG  Action       124
# 19              PG  Action       121
# 37              PG  Action       115
# ...

# %%
m_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
m_dataset["content_rating"].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
m_dataset[(m_dataset["star_rating"] >= 6) & (m_dataset["content_rating"] == "GP")].sort_values("star_rating",ascending= True).reset_index(drop=True)
# Out:
#    star_rating             title content_rating      genre  duration  \
# 0          7.7    Kelly's Heroes             GP     Action       144
# 1          8.0            Patton             GP  Biography       172
# 2          8.1  Harold and Maude             GP     Comedy        91
#
#                                          actors_list
# 0  [u'Clint Eastwood', u'Telly Savalas', u'Don Ri...
# 1  [u'George C. Scott', u'Karl Malden', u'Stephen...
# 2   [u'Ruth Gordon', u'Bud Cort', u'Vivian Pickles']
