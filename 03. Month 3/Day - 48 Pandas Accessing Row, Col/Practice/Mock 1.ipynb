# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\yashd\\02. Velocity Class Notes\\Class\\3. Month 3\\Day - 48 Pandas Accessing Row, Col\\Practice'

# %%
df = pd.read_csv("C:\\Users\\yashd\\02. Velocity Class Notes\\Class\\3. Month 3\\Day - 48 Pandas Accessing Row, Col\\Heart_Data.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
arr = np.random.randint(10,50,size=(5,5))
arr
arr_df = pd.DataFrame(arr,columns=list("ABCDE"),index=list("PQRST"))
arr_df
# Out:
#     A   B   C   D   E
# P  26  13  16  45  31
# Q  43  27  31  11  13
# R  12  47  39  44  43
# S  37  49  12  23  30
# T  21  32  34  10  29

# %%
arr_df[0:1]
# Out:
#     A   B   C   D   E
# P  26  13  16  45  31

# %%
arr_df["B"] = [1.5, 4.56, 6.6, 3.5, 4.8]
arr_df["A"] = ['1', '5', '4', '8', '7']

# %%
arr_df
# Out:
#    A     B   C   D   E          F
# P  1  1.50  16  45  31   1.0+5.0j
# Q  5  4.56  31  11  13   1.0+4.0j
# R  4  6.60  39  44  43   7.0+8.0j
# S  8  3.50  12  23  30  10.0+1.0j
# T  7  4.80  34  10  29   5.0+6.0j

# %%
arr_df["F"] = [1+5j, 1+4j, 7+8j, 10+1j, 5 + 6j]

# %%
arr_df
# Out:
#    A     B   C   D   E          F
# P  1  1.50  16  45  31   1.0+5.0j
# Q  5  4.56  31  11  13   1.0+4.0j
# R  4  6.60  39  44  43   7.0+8.0j
# S  8  3.50  12  23  30  10.0+1.0j
# T  7  4.80  34  10  29   5.0+6.0j

# %%
arr_df.dtypes
# Out:
# A        object
# B       float64
# C         int32
# D         int32
# E         int32
# F    complex128
# dtype: object

# %%
h = np.arange(1,5,dtype=float)
h.dtype
# Out:
# dtype('float64')

# %%
h = np.arange(1,5,dtype="float32")
h.dtype
# Out:
# dtype('float32')

# %%
h = np.arange(1,5,dtype=int)
h.dtype
# Out:
# dtype('int32')

# %%
h = np.arange(1,5,dtype="int64")
h.dtype
# Out:
# dtype('int64')

# %%
FFdata = df.head()
FFdata
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
FFdata.sort_values("age",ignore_index=True)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   37    1   2       130   250    0        1      187      0      3.5      0
# 1   41    0   1       130   204    0        0      172      0      1.4      2
# 2   56    1   1       120   236    0        1      178      0      0.8      2
# 3   57    0   0       120   354    0        1      163      1      0.6      2
# 4   63    1   3       145   233    1        0      150      0      2.3      0
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     1       1

# %%
FFdata.sort_values(["age","sex"],inplace=True)
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_2712\597417422.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FFdata.sort_values(["age","sex"],inplace=True)

# %%
FFdata
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 0   63    1   3       145   233    1        0      150      0      2.3      0
#
#    ca  thal  target
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 0   0     1       1

# %% [markdown]
# ## inplace=True
# Using the inplace=True keyword in a pandas method changes the default behaviour such that the operation on the dataframe doesn't return anything, it instead 'modifies the underlying data' (more on that later). It mutates the actual object which you apply it to

# %%
FFdata
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 0   63    1   3       145   233    1        0      150      0      2.3      0
#
#    ca  thal  target
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 0   0     1       1

# %%
FFdata["chol"]
# Out:
# 1    250
# 2    204
# 3    236
# 4    354
# 0    233
# Name: chol, dtype: int64

# %%
FFdata["chol"][1] = 5555555
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_2712\3098773353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FFdata["chol"][1] = 5555555

# %%
FFdata
# Out:
#    age  sex  cp  trestbps     chol  fbs  restecg  thalach  exang  oldpeak  \
# 1   37    1   2       130  5555555    0        1      187      0      3.5
# 2   41    0   1       130      204    0        0      172      0      1.4
# 3   56    1   1       120      236    0        1      178      0      0.8
# 4   57    0   0       120      354    0        1      163      1      0.6
# 0   63    1   3       145      233    1        0      150      0      2.3
#
#    slope  ca  thal  target
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1
# 0      0   0     1       1

# %%
FFdata.loc[[1,2,3],["age","trestbps", "slope"]]
# Out:
#    age  trestbps  slope
# 1   37       130      0
# 2   41       130      2
# 3   56       120      2
