# %% [markdown]
# # Access Rows and Columns

# %%
import pandas as pd
import numpy as np

# %%
emp_df = pd.read_excel("Employee_Records.xlsx")
emp_df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %% [markdown]
# # First N Rows

# %%
emp_df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
emp_df.head(10)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
# 6  539712      Nancy       22.14             50            0.87   98189
# 7  380086      Carol       59.12             40           34.52   60918
# 8  477616    Frances       58.18             42           23.27  121587
# 9  162402      Diana       29.73             60            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %% [markdown]
# # Last N ROws

# %%
emp_df.tail()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %%
emp_df.tail(10)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 90  185032     Eugene       37.84             59            2.64  122950
# 91  867084    Deborah       39.77             54           15.41   52767
# 92  969964     Janice       37.57             56            0.93  147641
# 93  158666    Rebecca       56.00             55           34.32  160043
# 94  489424    Phillip       39.43             82            1.56  181774
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#                        City
# 90                   Racine
# 91                  Atqasuk
# 92  Whiteman Air Force Base
# 93             Independence
# ...

# %% [markdown]
# # Accessing Columns
# - df_name[["ColumName"]] --> Single col
# - df_name[[ColumnNamesList]] ---> Multiple Col

# %%
emp_df["First Name"]
# Out:
# 0         Lois
# 1       Brenda
# 2          Joe
# 3        Diane
# 4     Benjamin
#         ...
# 95        Jose
# 96      Harold
# 97      Nicole
# 98     Theresa
# 99       Tammy
# Name: First Name, Length: 100, dtype: object

# %%
type(emp_df["First Name"])
# Out:
# pandas.core.series.Series

# %%
emp_df[["First Name"]]
# Out:
#    First Name
# 0        Lois
# 1      Brenda
# 2         Joe
# 3       Diane
# 4    Benjamin
# ..        ...
# 95       Jose
# 96     Harold
# 97     Nicole
# 98    Theresa
# 99      Tammy
#
# [100 rows x 1 columns]

# %%
emp_df[["Weight in Kgs"]]
# Out:
#     Weight in Kgs
# 0              60
# 1              60
# 2              68
# 3              51
# 4              58
# ..            ...
# 95             89
# 96             77
# 97             60
# 98             57
# 99             55
#
# [100 rows x 1 columns]

# %%
col_li = ['Age in Yrs','Weight in Kgs', 'Age in Company']
emp_df[col_li]
# Out:
#     Age in Yrs  Weight in Kgs  Age in Company
# 0        36.36             60           13.68
# 1        47.02             60            9.01
# 2        54.15             68            0.98
# 3        39.67             51           18.30
# 4        40.31             58            4.01
# ..         ...            ...             ...
# 95       22.82             89            1.05
# 96       32.61             77            5.93
# 97       52.66             60           28.53
# 98       29.60             57            6.99
# 99       38.38             55            2.26
#
# [100 rows x 3 columns]

# %%
emp_df[["Emp ID","Salary"]]
# Out:
#     Emp ID  Salary
# 0   677509  168251
# 1   940761   51063
# 2   428945   50155
# 3   408351  180294
# 4   193819  117642
# ..     ...     ...
# 95  639892  129774
# 96  704709  156194
# 97  461593   95673
# 98  392491   51015
# 99  495141   93650
#
# [100 rows x 2 columns]

# %% [markdown]
# # Rows by slicing method

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df[0]
emp_df["First Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
emp_df[0:1]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
#
#      City
# 0  Denver

# %%
emp_df[0:3]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown

# %%
emp_df[7:16]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 7   380086      Carol       59.12             40           34.52   60918
# 8   477616    Frances       58.18             42           23.27  121587
# 9   162402      Diana       29.73             60            3.44   43010
# 10  231469      Ralph       42.50             80            8.29  118457
# 11  153989       Jack       22.21             61            0.56   82965
# 12  386158    Melissa       45.45             55            1.68  166892
# 13  301576      Wayne       21.10             87            0.02   92758
# 14  441771     Cheryl       59.47             47           26.69   92220
# 15  528509      Paula       50.97             42           22.95  152654
#
#               City
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas
# 12   New Matamoras
# 13           Maida
# 14        Quecreek
# 15      Beulaville

# %%
emp_df[95:]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %% [markdown]
# # iloc[]
# - df.iloc[row_index,col_index]

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.iloc[:,:]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.iloc[0:3,:]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36             60           13.68  168251
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown

# %%
emp_df.iloc[0:3,:1]
# Out:
#    Emp ID
# 0  677509
# 1  940761
# 2  428945

# %%
emp_df.iloc[0:3,1:6]
# Out:
#   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary
# 0       Lois       36.36             60           13.68  168251
# 1     Brenda       47.02             60            9.01   51063
# 2        Joe       54.15             68            0.98   50155

# %%
emp_df.iloc[[0,5,50],[5,1]]
# Out:
#     Salary First Name
# 0   168251       Lois
# 5    72305    Patrick
# 50   97904      Larry

# %% [markdown]
# # loc[]
# - df.loc[RowLabel,ColLabel]

# %%
emp_df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
emp_df.loc[1:5,:]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 1  940761     Brenda       47.02             60            9.01   51063
# 2  428945        Joe       54.15             68            0.98   50155
# 3  408351      Diane       39.67             51           18.30  180294
# 4  193819   Benjamin       40.31             58            4.01  117642
# 5  499687    Patrick       34.86             58           12.02   72305
#
#            City
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont
# 5     Macksburg

# %%
emp_df.loc[1:5,"First Name"]
# Out:
# 1      Brenda
# 2         Joe
# 3       Diane
# 4    Benjamin
# 5     Patrick
# Name: First Name, dtype: object

# %%
emp_df.loc[1:5,"First Name":"Salary"]
# Out:
#   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary
# 1     Brenda       47.02             60            9.01   51063
# 2        Joe       54.15             68            0.98   50155
# 3      Diane       39.67             51           18.30  180294
# 4   Benjamin       40.31             58            4.01  117642
# 5    Patrick       34.86             58           12.02   72305

# %%
emp_df.loc[[5,1,3],["Age in Yrs","Salary",'First Name']]
# Out:
#    Age in Yrs  Salary First Name
# 5       34.86   72305    Patrick
# 1       47.02   51063     Brenda
# 3       39.67  180294      Diane
