# %%
# !pip install pytessract
# Out:
# ERROR: Could not find a version that satisfies the requirement pytessract (from versions: none)
# ERROR: No matching distribution found for pytessract

# %% [markdown]
# - path shuld be exactly same r"C:\Program Files (x86)\Tesseract_OCR\tesseract.exe"
# - command :-  ! pip install pytesseract

# %%
# ! pip install pytesseract

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\yashd\\02. Velocity Class Notes\\Class\\3. Month 3\\Day - 57 Pyteseeract'

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"

# %%
pan_data = pytesseract.image_to_string("download.jpg")
print(pan_data)
# Out:
# “orev fears
#
# ‘INOOMBTAX DEPARTMENT
# DMANIKANDAN
#
# DURAISAMY
# ‘wo711986
#
# BNzeMasoIF
#
# Dooakaasthey
# sownee ?

# %%
data = pytesseract.image_to_string("IMG-20190703-WA0016(1).jpg")

# %%
print(data)
# Out:
# Avni
# ANN
# ANN
#
# Ni
#
# i
# IRR TT PRPPPPTTTTTTT PPPOE PSSA
#
# bande_shubhangi.ghrcemace@raisoni-_net ghrcemal234 /
#
# nimbalkar_sumedh.ghrcemace@raisoni-net ghrcemai234 /
# rathod_akash.ghrcemace@raisoni.net ghreemal234 | /
#
# Gawai gawai_swapnil.ghrcemace@raisoni.net ghroema1234 /
#
# Syed syed_ayyub.ghrcemace@raisoni.net ghrcemai234 |/
#
# 63 Husain Husain husain_husain.ghrcemace @raisoni.net ghrcemai234 /
# 64 Vedika Chandurkar chandurkar_vedika.ghrcemace@raisoni.net ghrcemai234 |/
# 65 Vikalp Kale kale_vikalp.ghrcemace@raisoni.net ghrcemai234 /
# 66 Vishal Bramhane —_ bramhane_vishal.ghrcemace@raisoni.net ghrcemai234. /
# 67 Yash Dhakade  dhakade_yash.ghrcemace@raisoni.net ghrcema1234 /
# 68 Sayyed Hussain hussain_sayyed.ghrcemace@raisoni,net ghrcemai234 /
# 69 Vaibhav —_Katole katole_vaibhav.ghrcemace@raisoni.net ghrcemai234 /
# 70 Aniket Dongare dongare_aniket.ghrcemace@raisoni.net ghrcemai234 /
#
# Ti Aniket Kene
# 72 Atif Khan
#
# ...

# %%
import pandas as pd

# %%
data1 = pytesseract.image_to_data("download.jpg",output_type='data.frame')

# %%
display(data1)
# Out:
#     level  page_num  block_num  par_num  line_num  word_num  left  top  width  \
# 0       1         1          0        0         0         0     0    0    284
# 1       2         1          1        0         0         0     0    0    120
# 2       3         1          1        1         0         0     0    0    120
# 3       4         1          1        1         1         0     0    0    120
# 4       5         1          1        1         1         1     0    0     56
# 5       5         1          1        1         1         2    77    0     46
# 6       2         1          2        0         0         0     8   31    112
# 7       3         1          2        1         0         0     8   31    112
# 8       4         1          2        1         1         0     8   31    112
# 9       5         1          2        1         1         1     8   31     53
# 10      5         1          2        1         1         2    64   31     56
# ...

# %%
data2 = pytesseract.image_to_boxes("download.jpg",)
print(data2)
# Out:
# “ 0 145 14 177 0
# o 13 145 22 177 0
# r 21 145 30 177 0
# e 0 155 56 177 0
# v 40 145 56 177 0
# f 77 145 83 177 0
# e 82 145 94 177 0
# a 77 155 120 170 0
# r 101 145 110 177 0
# s 109 145 123 177 0
# ‘ 8 136 9 146 0
# I 8 136 14 146 0
# N 8 136 18 146 0
# O 18 136 23 146 0
# O 18 136 30 146 0
# M 29 136 37 146 0
# B 30 136 44 146 0
# T 43 136 51 146 0
# A 45 136 61 146 0
# X 55 136 60 146 0
# D 64 136 69 146 0
# E 69 136 74 146 0
# P 74 136 79 146 0
# A 78 136 86 146 0
# R 70 136 108 146 0
# T 90 136 95 146 0
# M 95 136 102 146 0
# E 102 136 109 146 0
# N 109 136 114 146 0
# T 109 136 120 146 0
# D 14 122 20 129 0
# M 23 122 30 129 0
# A 31 122 37 129 0
# N 37 122 46 129 0
# I 42 122 48 129 0
# K 47 122 59 129 0
# A 54 122 59 129 0
# N 60 122 66 129 0
# D 67 122 73 129 0
# A 73 122 79 129 0
# N 80 122 86 129 0
# ~ 136 127 168 165 0
# D 14 98 20 105 0
# U 19 98 27 105 0
# R 21 98 33 105 0
# A 34 98 39 105 0
# I 40 98 42 105 0
# S 42 98 48 105 0
# A 43 98 54 105 0
# ...

# %%
print(pytesseract.image_to_pdf_or_hocr("download.jpg",extension='pdf'))
# Out:
# b'%PDF-1.5\n%\xde\xad\xbe\xeb\n1 0 obj\n<<\n  /Type /Catalog\n  /Pages 2 0 R\n>>\nendobj\n3 0 obj\n<<\n  /BaseFont /GlyphLessFont\n  /DescendantFonts [ 4 0 R ]\n  /Encoding /Identity-H\n  /Subtype /Type0\n  /ToUnicode 6 0 R\n  /Type /Font\n>>\nendobj\n4 0 obj\n<<\n  /BaseFont /GlyphLessFont\n  /CIDToGIDMap 5 0 R\n  /CIDSystemInfo\n  <<\n     /Ordering (Identity)\n     /Registry (Adobe)\n     /Supplement 0\n  >>\n  /FontDescriptor 7 0 R\n  /Subtype /CIDFontType2\n  /Type /Font\n  /DW 500\n>>\nendobj\n5 0 obj\n<<\n  /Length 210 /Filter /FlateDecode\n>>\nstream\nx\x9c\xec\xc2\x01\t\x00\x00\x00\x02\xa0\xfa\x7f\xba!\x89\xa6\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80{\x03\x00\x00\xff\xff\xec\xc2\x01\r\x00\x00\x00\xc2 \xdf\xbf\xb4E\x18\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xeb\x00\x00\x00\xff\xff\xec\xc2\x01\r\x00\x00\
# ...

# %%
print(pytesseract.image_to_alto_xml("download.jpg"))
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<alto xmlns="http://www.loc.gov/standards/alto/ns-v3#" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/standards/alto/ns-v3# http://www.loc.gov/alto/v3/alto-3-0.xsd">\n\t<Description>\n\t\t<MeasurementUnit>pixel</MeasurementUnit>\n\t\t<sourceImageInformation>\n\t\t\t<fileName>C:\\Users\\yashd\\02. Velocity Class Notes\\Class\\3. Month 3\\Day - 57 Pyteseeract\\download.jpg</fileName>\n\t\t</sourceImageInformation>\n\t\t<OCRProcessing ID="OCR_0">\n\t\t\t<ocrProcessingStep>\n\t\t\t\t<processingSoftware>\n\t\t\t\t\t<softwareName>tesseract v5.2.0.20220712</softwareName>\n\t\t\t\t</processingSoftware>\n\t\t\t</ocrProcessingStep>\n\t\t</OCRProcessing>\n\t</Description>\n\t<Layout>\n\t\t<Page WIDTH="284" HEIGHT="177" PHYSICAL_IMG_NR="0" ID="page_0">\n\t\t\t<PrintSpace HPOS="0" VPOS="0" WIDTH="284" HEIGHT="177">\n\t\t\t\t<ComposedBlock ID="cblock_0" HPOS="0" VPOS="
# ...
