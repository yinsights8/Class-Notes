# %%
import pandas as pd
import numpy as np

# %%
Emp_rec = pd.read_csv("Emp_Records.csv")
display(Emp_rec)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
Top_Five = Emp_rec.head(10)
Top_Five
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36           60.0           13.68  168251
# 1  940761     Brenda       47.02           60.0            9.01   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351        NaN       39.67           51.0           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
# 5  499687    Patrick       34.86           58.0           12.02   72305
# 6  539712      Nancy       22.14           50.0            0.87   98189
# 7  380086        NaN       59.12           40.0           34.52   60918
# 8  477616    Frances       58.18           42.0           23.27  121587
# 9  162402      Diana       29.73           60.0            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
Last_Five = Emp_rec.tail(10)
Last_Five
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 90  185032     Eugene       37.84           59.0            2.64  122950
# 91  867084    Deborah       39.77           54.0           15.41   52767
# 92  969964     Janice       37.57           56.0            0.93  147641
# 93  158666    Rebecca       56.00           55.0           34.32  160043
# 94  489424    Phillip       39.43           82.0            1.56  181774
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#                        City
# 90                   Racine
# 91                  Atqasuk
# 92  Whiteman Air Force Base
# 93             Independence
# ...

# %%
Top_Five.isna()
# Out:
#    Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   False       False       False          False           False   False
# 1   False       False       False          False           False   False
# 2   False       False       False          False           False   False
# 3   False        True       False          False           False   False
# 4   False       False       False          False           False   False
# 5   False       False       False          False           False   False
# 6   False       False       False          False           False   False
# 7   False        True       False          False           False   False
# 8   False       False       False          False           False   False
# 9   False       False       False          False           False   False
#
#     City
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
# 5  False
# 6  False
# 7  False
# 8  False
# 9  False

# %%
Top_Five.isna().sum()
# Out:
# Emp ID            0
# First Name        2
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
Last_Five.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 90   False       False       False          False           False   False
# 91   False       False       False          False           False   False
# 92   False       False       False          False           False   False
# 93   False       False       False          False           False   False
# 94   False       False       False          False           False   False
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 90  False
# 91  False
# 92  False
# 93  False
# 94  False
# 95  False
# 96  False
# 97  False
# 98  False
# 99  False

# %% [markdown]
# # appending head() rows and tail() rows by using head() and tail() simulteniously

# %%
rows = 2
Emp_rec.head(rows).append(Emp_rec.tail(rows))
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_16084\1145615625.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Emp_rec.head(rows).append(Emp_rec.tail(rows))
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#          City
# 0      Denver
# 1   Stonewall
# 98   Mc Grath
# 99       Alma

# %%
display(Top_Five)
display(Last_Five)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36           60.0           13.68  168251
# 1  940761     Brenda       47.02           60.0            9.01   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351        NaN       39.67           51.0           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
# 5  499687    Patrick       34.86           58.0           12.02   72305
# 6  539712      Nancy       22.14           50.0            0.87   98189
# 7  380086        NaN       59.12           40.0           34.52   60918
# 8  477616    Frances       58.18           42.0           23.27  121587
# 9  162402      Diana       29.73           60.0            3.44   43010
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# ...

# %%
Top_Five.append(Last_Five)
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_16084\2348755484.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Top_Five.append(Last_Five)
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 5   499687    Patrick       34.86           58.0           12.02   72305
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 7   380086        NaN       59.12           40.0           34.52   60918
# 8   477616    Frances       58.18           42.0           23.27  121587
# ...

# %%
Emp_rec.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36           60.0           13.68  168251
# 1  940761     Brenda       47.02           60.0            9.01   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351        NaN       39.67           51.0           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
Emp_rec.tail()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %%
Emp_rec.head().append(Emp_rec.tail())
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_16084\362954431.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Emp_rec.head().append(Emp_rec.tail())
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# ...

# %% [markdown]
# ## same operation with pd.cocat() method

# %%
pd.concat(Emp_rec.head(), Emp_rec.tail())
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_16084\81032425.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   pd.concat(Emp_rec.head(), Emp_rec.tail())
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 pd.concat(Emp_rec.head(), Emp_rec.tail())
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
Emp_rec[1:5]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 1  940761     Brenda       47.02           60.0            9.01   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351        NaN       39.67           51.0           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
pd.concat([Emp_rec[1:5], Emp_rec[6:10]])
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 1  940761     Brenda       47.02           60.0            9.01   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351        NaN       39.67           51.0           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
# 6  539712      Nancy       22.14           50.0            0.87   98189
# 7  380086        NaN       59.12           40.0           34.52   60918
# 8  477616    Frances       58.18           42.0           23.27  121587
# 9  162402      Diana       29.73           60.0            3.44   43010
#
#              City
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 6         Atlanta
# 7     Blanchester
# 8         Delmita
# 9  Eureka Springs

# %%
[Emp_rec[1:5], Emp_rec[6:10]]
# Out:
# [   Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
#  1  940761     Brenda       47.02           60.0            9.01   51063
#  2  428945        Joe       54.15           68.0            0.98   50155
#  3  408351        NaN       39.67           51.0           18.30  180294
#  4  193819   Benjamin       40.31           58.0            4.01  117642
#
#             City
#  1     Stonewall
#  2  Michigantown
#  3      Hydetown
#  4       Fremont  ,
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
#  6  539712      Nancy       22.14           50.0            0.87   98189
#  7  380086        NaN       59.12           40.0           34.52   60918
#  8  477616    Frances       58.18           42.0           23.27  121587
#  9  162402      Diana       29.73           60.0            3.44   43010
#
#               City
#  6         Atlanta
#  7     Blanchester
#  8         Delmita
#  9  Eureka Springs  ]

# %%
Top_Five.isna().sum()
# Out:
# Emp ID            0
# First Name        2
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
Emp_rec[Emp_rec.isna().any(axis=1)]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 3   408351        NaN       39.67           51.0           18.30  180294
# 7   380086        NaN       59.12           40.0           34.52   60918
# 10  231469        NaN       42.50           80.0            8.29  118457
# 14  441771        NaN       59.47           47.0           26.69   92220
# 18  890290      Julia         NaN           56.0           12.43  141518
# 19  622406     Thomas         NaN           73.0           19.15   73862
# 20  979607        NaN       22.64           56.0            1.26   93967
# 24  560455    Carolyn         NaN           53.0           16.08   42005
# 27  683826      Roger         NaN           77.0            8.50  129625
# 28  474599      Maria       42.39            NaN             NaN   48944
# 29  335732     Brenda       53.68            NaN             NaN   60508
# 30  329752    Lillian       36.24            NaN             NaN   67251
# ...

# %%
Emp_rec[Emp_rec["First Name"].isna()]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 3   408351        NaN       39.67           51.0           18.30  180294
# 7   380086        NaN       59.12           40.0           34.52   60918
# 10  231469        NaN       42.50           80.0            8.29  118457
# 14  441771        NaN       59.47           47.0           26.69   92220
# 20  979607        NaN       22.64           56.0            1.26   93967
# 32  621833        NaN       23.92            NaN            1.83  169245
#
#            City
# 3      Hydetown
# 7   Blanchester
# 10      Sabetha
# 14     Quecreek
# 20   Shreveport
# 32      Bonanza

# %%
Emp_rec["Age in Yrs"].fillna(Emp_rec["Age in Yrs"].mean(),inplace=True)

# %%
Emp_rec[Emp_rec["Age in Yrs"].isna()]
# Out:
# Empty DataFrame
# Columns: [Emp ID, First Name, Age in Yrs, Weight in Kgs, Age in Company, Salary, City]
# Index: []

# %%
Emp_rec[Emp_rec.isna().any(axis=1)]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 3   408351        NaN       39.67           51.0           18.30  180294
# 7   380086        NaN       59.12           40.0           34.52   60918
# 10  231469        NaN       42.50           80.0            8.29  118457
# 14  441771        NaN       59.47           47.0           26.69   92220
# 18  890290      Julia         NaN           56.0           12.43  141518
# 19  622406     Thomas         NaN           73.0           19.15   73862
# 20  979607        NaN       22.64           56.0            1.26   93967
# 24  560455    Carolyn         NaN           53.0           16.08   42005
# 27  683826      Roger         NaN           77.0            8.50  129625
# 28  474599      Maria       42.39            NaN             NaN   48944
# 29  335732     Brenda       53.68            NaN             NaN   60508
# 30  329752    Lillian       36.24            NaN             NaN   67251
# ...

# %%
Emp_rec[36:40]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron   38.303222            NaN           20.08   54402
# 37  134841      Donna   38.303222           57.0            4.03  129836
# 38  726264       Carl   38.303222           90.0           10.14  162159
# 39  766610      Joyce   38.303222           44.0            7.21  119321
#
#          City
# 36    Eckerty
# 37       Lima
# 38     Wright
# 39  Ellsworth

# %%
Emp_rec["Weight in Kgs"].fillna(Emp_rec["Weight in Kgs"].median(),inplace=True)

# %%
Emp_rec[36:40]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron   38.303222           56.5           20.08   54402
# 37  134841      Donna   38.303222           57.0            4.03  129836
# 38  726264       Carl   38.303222           90.0           10.14  162159
# 39  766610      Joyce   38.303222           44.0            7.21  119321
#
#          City
# 36    Eckerty
# 37       Lima
# 38     Wright
# 39  Ellsworth
