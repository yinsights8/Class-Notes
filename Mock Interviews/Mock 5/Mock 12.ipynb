# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Emp_Records.csv")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251
# 1   940761     Brenda       47.02           60.0            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351        NaN       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      94 non-null     object
#  2   Age in Yrs      90 non-null     float64
#  3   Weight in Kgs   90 non-null     float64
#  4   Age in Company  91 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            94 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36           60.0           13.68  168251
# 1  940761     Brenda       47.02           60.0            9.01   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351        NaN       39.67           51.0           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 0        Denver
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
df.tail()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %%
df.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000   90.000000      90.000000       91.000000     100.000000
# mean   547652.10000   38.303222      58.533333        8.801868  119738.090000
# std    257664.16679   11.843545      12.232945        8.367442   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   27.802500      51.000000        2.300000   83979.750000
# 50%    497414.00000   36.300000      56.500000        6.940000  118049.500000
# 75%    766040.00000   48.537500      61.000000       13.305000  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False          False           False   False
# 3    False        True       False          False           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isna().sum()
# Out:
# Emp ID             0
# First Name         6
# Age in Yrs        10
# Weight in Kgs     10
# Age in Company     9
# Salary             0
# City               6
# dtype: int64

# %%
# df.index.tolist()
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.columns
# Out:
# Index(['Emp ID', 'First Name', 'Age in Yrs', 'Weight in Kgs', 'Age in Company',
#        'Salary', 'City'],
#       dtype='object')

# %%
r_df = pd.DataFrame({
    "Name":["yash", "Niranjan", "Komal", "Priti"],
    "Id" : [1,2,3,4]
})

# %%
rdx = pd.DataFrame(r_df)
rdx
# Out:
#        Name  Id
# 0      yash   1
# 1  Niranjan   2
# 2     Komal   3
# 3     Priti   4

# %%
rdx.columns = list("AB")

# %%
rdx
# Out:
#           A  B
# 0      yash  1
# 1  Niranjan  2
# 2     Komal  3
# 3     Priti  4

# %%
rdx.index = list("abcd")

# %%
rdx
# Out:
#           A  B
# a      yash  1
# b  Niranjan  2
# c     Komal  3
# d     Priti  4

# %%
rdx.sort_values(["A", "B"])
# Out:
#           A  B
# c     Komal  3
# b  Niranjan  2
# d     Priti  4
# a      yash  1

# %%
rdx.sort_index(axis=0,ascending=True)
# Out:
#           A  B
# a      yash  1
# b  Niranjan  2
# c     Komal  3
# d     Priti  4

# %%
rdx.drop("B",axis=1)
# Out:
#           A
# a      yash
# b  Niranjan
# c     Komal
# d     Priti

# %%
rdx
# Out:
#           A  B
# a      yash  1
# b  Niranjan  2
# c     Komal  3
# d     Priti  4

# %%
rdx
# Out:
#           A  B
# a      yash  1
# b  Niranjan  2
# c     Komal  3
# d     Priti  4

# %%
priti = pd.DataFrame({
    "Name":["yash", "Niranjan", "Komal", "Priti"],
    "Id" : [1,np.nan,3,np.nan],
    "Loc" : ["Pune", "Mumbai", "Gujarat", "Banglore"]
})

# %%
priti
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
priti.isna().sum()
# Out:
# Name    0
# Id      2
# Loc     0
# dtype: int64

# %%
priti.dropna(axis=1)
# Out:
#        Name       Loc
# 0      yash      Pune
# 1  Niranjan    Mumbai
# 2     Komal   Gujarat
# 3     Priti  Banglore

# %%
priti.dropna(axis=0)
# Out:
#     Name   Id      Loc
# 0   yash  1.0     Pune
# 2  Komal  3.0  Gujarat

# %%
priti
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
priti.fillna(priti["Id"].mean())
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  2.0    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  2.0  Banglore

# %%
priti[["Id"]].fillna(500)
# Out:
#       Id
# 0    1.0
# 1  500.0
# 2    3.0
# 3  500.0

# %%
new_data = priti.copy()

# %%
new_data
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data.shape
# Out:
# (4, 3)

# %%
new_data.size
# Out:
# 12

# %%
new_data.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['Name', 'Id', 'Loc'], dtype='object')]

# %%
new_data.dtypes
# Out:
# Name     object
# Id      float64
# Loc      object
# dtype: object

# %% [markdown]
# ## Accesing DataFrame

# %%
new_data
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data[["Name"]]
# Out:
#        Name
# 0      yash
# 1  Niranjan
# 2     Komal
# 3     Priti

# %%
new_data[["Name", "Id", "Loc"]]
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data.loc[0:1,["Name", "Id"]]
# Out:
#        Name   Id
# 0      yash  1.0
# 1  Niranjan  NaN

# %%
new_data.iloc[0:2,:]
# Out:
#        Name   Id     Loc
# 0      yash  1.0    Pune
# 1  Niranjan  NaN  Mumbai

# %%
new_data.iloc[0:2,1:]
# Out:
#     Id     Loc
# 0  1.0    Pune
# 1  NaN  Mumbai

# %% [markdown]
# ## Dauly use Functions

# %%
movis = pd.read_csv("movies_data.csv")

# %%
movis.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movis.value_counts("genre").to_dict()
# Out:
# {'Drama': 278,
#  'Comedy': 156,
#  'Action': 136,
#  'Crime': 124,
#  'Biography': 77,
#  'Adventure': 75,
#  'Animation': 62,
#  'Horror': 29,
#  'Mystery': 16,
#  'Western': 9,
#  'Sci-Fi': 5,
#  'Thriller': 5,
#  'Film-Noir': 3,
#  'Family': 2,
#  'Fantasy': 1,
#  'History': 1}

# %%
movis["genre"].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movis["genre"].nunique()
# Out:
# 16

# %%
new_data
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data.replace("yash", "Y")
# Out:
#        Name   Id       Loc
# 0         Y  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data.replace({"yash": "Y", "Niranjan" : "N", "Komal": "K", "Priti": "P"})
# Out:
#   Name   Id       Loc
# 0    Y  1.0      Pune
# 1    N  NaN    Mumbai
# 2    K  3.0   Gujarat
# 3    P  NaN  Banglore

# %%
new_data.replace("Mumbai", "Bankig")
# Out:
#        Name   Id       Loc
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Bankig
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data.rename({0:"1st", 1:"2nd", 2:"3rd", 3:"4rth"})
# Out:
#           Name   Id       Loc
# 1st       yash  1.0      Pune
# 2nd   Niranjan  NaN    Mumbai
# 3rd      Komal  3.0   Gujarat
# 4rth     Priti  NaN  Banglore

# %%
new_data.rename(columns={"Name":"A", 'Id':"B", "Loc":"C"})
# Out:
#           A    B         C
# 0      yash  1.0      Pune
# 1  Niranjan  NaN    Mumbai
# 2     Komal  3.0   Gujarat
# 3     Priti  NaN  Banglore

# %%
new_data.insert(0,"F",[1,2,3,4])

# %%
new_data
# Out:
#    F      Name   Id       Loc
# 0  1      yash  1.0      Pune
# 1  2  Niranjan  NaN    Mumbai
# 2  3     Komal  3.0   Gujarat
# 3  4     Priti  NaN  Banglore

# %%
new_data.insert(2,"KAKA",[1,2,3,4])

# %%
new_data
# Out:
#    F      Name  KAKA   Id       Loc
# 0  1      yash     1  1.0      Pune
# 1  2  Niranjan     2  NaN    Mumbai
# 2  3     Komal     3  3.0   Gujarat
# 3  4     Priti     4  NaN  Banglore

# %%
new_data[["KAKA"]].astype(float)
# Out:
#    KAKA
# 0   1.0
# 1   2.0
# 2   3.0
# 3   4.0

# %%
new_data
# Out:
#    F      Name  KAKA   Id       Loc
# 0  1      yash     1  1.0      Pune
# 1  2  Niranjan     2  NaN    Mumbai
# 2  3     Komal     3  3.0   Gujarat
# 3  4     Priti     4  NaN  Banglore

# %%
new_data[["KAKA"]].apply(lambda x : x**5)
# Out:
#    KAKA
# 0     1
# 1    32
# 2   243
# 3  1024

# %%
p = pd.DataFrame(new_data["Loc"].apply(lambda x : x.swapcase()))

# %%
"Loc".swapcase()
# Out:
# 'lOC'

# %%
p
# Out:
#         Loc
# 0      pUNE
# 1    mUMBAI
# 2   gUJARAT
# 3  bANGLORE

# %%
df1 = pd.DataFrame({
    "name" : ['A', "B", "C"],
    'id' : [1,2,3]
})

# %%
df2 = pd.DataFrame({
    "name" : ['P', "Q", "R"],
    'id' : [11,12,13]
})

# %%
df3 = df1.append(df2)
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_720\3559124262.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df1.append(df2)

# %%
df3
# Out:
#   name  id
# 0    A   1
# 1    B   2
# 2    C   3
# 0    P  11
# 1    Q  12
# 2    R  13

# %%
df1
# Out:
#   name  id
# 0    A   1
# 1    B   2
# 2    C   3

# %%
df2
# Out:
#   name  id
# 0    P  11
# 1    Q  12
# 2    R  13

# %%
df3 = pd.concat([df1,df2])

# %%
df3
# Out:
#   name  id
# 0    A   1
# 1    B   2
# 2    C   3
# 0    P  11
# 1    Q  12
# 2    R  13

# %%
df3 = pd.concat([df1,df2],axis=1,keys=["df1","df2"])

# %%
df3
# Out:
#    df1     df2
#   name id name  id
# 0    A  1    P  11
# 1    B  2    Q  12
# 2    C  3    R  13

# %%
movis.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movis["genre"].value_countsunts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movis.groupby("content_rating").first()
# Out:
#                 star_rating                                           title  \
# content_rating
# APPROVED                8.7                           It's a Wonderful Life
# G                       8.6                                    Modern Times
# GP                      8.1                                Harold and Maude
# NC-17                   7.9                       Blue Is the Warmest Color
# NOT RATED               8.9                                    12 Angry Men
# PASSED                  8.6                                     City Lights
# PG                      8.8  Star Wars: Episode V - The Empire Strikes Back
# PG-13                   9.0                                 The Dark Knight
# R                       9.3                        The Shawshank Redemption
# TV-MA                   8.1                 Who's Afraid of Virginia Woolf?
# UNRATED                 8.7                                   Seven Samurai
# ...

# %%
movis.groupby("content_rating").get_group("TV-MA")
# Out:
#      star_rating                            title content_rating  genre  \
# 219          8.1  Who's Afraid of Virginia Woolf?          TV-MA  Drama
#
#      duration                                        actors_list
# 219       131  [u'Elizabeth Taylor', u'Richard Burton', u'Geo...

# %%
movis.groupby(["content_rating", "genre"]).get_group(("PG-13","Action"))
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 43           8.5                            The Dark Knight Rises
# 113          8.3                                    Batman Begins
# 118          8.3               Indiana Jones and the Last Crusade
# 177          8.2                                     The Avengers
# 196          8.1                          Guardians of the Galaxy
# 240          8.1                             The Bourne Ultimatum
# 248          8.1                       X-Men: Days of Future Past
# 301          8.0                                        Furious 7
# 312          8.0                                        Star Trek
# 366          8.0                                         Serenity
# 380          8.0                                    Casino Royale
# ...

# %%
movis[movis["star_rating"] == 8.0]
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 297          8.0                   Rope             PG      Crime        80
# 298          8.0           The Graduate       APPROVED     Comedy       106
# 299          8.0          Jurassic Park          PG-13  Adventure       127
# 300          8.0               Dogville              R      Crime       178
# 301          8.0              Furious 7          PG-13     Action       137
# ..           ...                    ...            ...        ...       ...
# 389          8.0                 Freaks        UNRATED      Drama        64
# 390          8.0  Letters from Iwo Jima              R      Drama       141
# 391          8.0       Edge of Tomorrow          PG-13     Action       113
# 392          8.0                  Glory              R      Drama       122
# 393          8.0      The African Queen             PG  Adventure       105
#
#                                            actors_list
# ...

# %%
movis[movis["star_rating"] >= 9]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
